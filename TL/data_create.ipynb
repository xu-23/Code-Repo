# %%
# Dependencies: numpy, matplotlib, pandas
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import time
import cantera as ct

print('Running Cantera version: ' + ct.__version__)

def ignition_delay(states, species):
    """计算点火延迟时间"""
    i_ign = states(species).Y.argmax()
    return states.t[i_ign], states.T[i_ign]

def run_simulation(T, P, phi):
    """运行单个条件下的模拟"""
    # 创建气体对象并设置状态
    ideal_gas = ct.Solution('~/0/yaml/Burke2012_s9r23.yaml')
    ideal_gas.TP = T, P * 101325.0  # 转换为帕斯卡
    
    # 设置当量比
    ideal_gas.set_equivalence_ratio(phi=phi, fuel='H2',
                                    oxidizer={'O2': 1.0, 'N2': 3.76})
    
    # 创建反应器网络
    r = ct.Reactor(ideal_gas)
    reactor_network = ct.ReactorNet([r])
    time_history_IG = ct.SolutionArray(ideal_gas, extra=['t'])
    
    # 运行模拟
    t = 0
    counter = 1
    estimated_ignition_delay_time = 0.005
    
    while t < estimated_ignition_delay_time:
        t = reactor_network.step()
        if counter % 20 == 0:
            time_history_IG.append(r.thermo.state, t=t)
        counter += 1
    
    # 计算点火延迟
    tau_IG, _ = ignition_delay(time_history_IG, 'oh')
    
    return tau_IG

def main():
    """主函数：循环计算所有条件并保存结果"""
    # 定义参数范围
    T_range = np.arange(1100, 1525, 25)  # 1100-1500K，间隔25K
    P_range = np.arange(0.8, 1.21, 0.1)  # 0.8-1.2atm，间隔0.1atm
    phi_range = np.arange(0.8, 1.21, 0.1)  # 0.8-1.2，间隔0.1
    
    # 准备存储结果的列表
    results = []
    
    total_cases = len(T_range) * len(P_range) * len(phi_range)
    print(f"总计算条件数: {total_cases}")
    
    start_time = time.time()
    case_count = 0
    
    # 三重循环计算所有条件
    for T in T_range:
        for P in P_range:
            for phi in phi_range:
                case_count += 1
                
                print(f"计算进度: {case_count}/{total_cases} "
                      f"(T={T}K, P={P}atm, phi={phi})")
                
                try:
                    tau_IG = run_simulation(T, P, phi)
                    
                    # 保存结果
                    results.append({
                        'Temperature_K': T/1000,
                        'Pressure_atm': P,
                        'Equivalence_Ratio': phi,
                        'Ignition_Delay_s': tau_IG
                    })
                    
                    print(f"  点火延迟: {tau_IG:.3e} s")
                    
                except Exception as e:
                    print(f"  计算失败: {e}")
                    # 失败时保存NaN值
                    results.append({
                        'Temperature_K': T,
                        'Pressure_atm': P,
                        'Equivalence_Ratio': phi,
                        'Ignition_Delay_s': np.nan
                    })
    
    end_time = time.time()
    print(f"\n总计算时间: {end_time - start_time:.2f} 秒")
    
    # 转换为DataFrame并保存为CSV
    df_results = pd.DataFrame(results)
    df_results.to_csv('ignition_delay_results.csv', index=False)
    print("\n结果已保存到 'ignition_delay_results.csv'")
    
    # 显示前几行数据
    print("\n前5行数据预览:")
    print(df_results.head())
    
    # 统计成功计算的数量
    successful = df_results['Ignition_Delay_s'].notna().sum()
    print(f"\n成功计算: {successful}/{total_cases}")
    
    return df_results

if __name__ == "__main__":
    # 运行主程序
    data = main()
    
    # 读取CSV文件的示例（后续分析使用）
    # data_A = pd.read_csv('ignition_delay_results.csv')
    # 假设特征在前，标签在最后一列
    # X = data_A.iloc[:, :-1].values  # 特征（温度、压力、当量比）
    # y = data_A.iloc[:, -1].values    # 标签（点火延迟）
# Out:
# Running Cantera version: 3.1.0
# 总计算条件数: 425
# 计算进度: 1/425 (T=1100K, P=0.8atm, phi=0.8)
#   点火延迟: 1.431e-04 s
# 计算进度: 2/425 (T=1100K, P=0.8atm, phi=0.9)
#   点火延迟: 1.398e-04 s
# 计算进度: 3/425 (T=1100K, P=0.8atm, phi=1.0)
#   点火延迟: 1.378e-04 s
# 计算进度: 4/425 (T=1100K, P=0.8atm, phi=1.1)
#   点火延迟: 1.370e-04 s
# 计算进度: 5/425 (T=1100K, P=0.8atm, phi=1.2)
#   点火延迟: 1.348e-04 s
# 计算进度: 6/425 (T=1100K, P=0.9atm, phi=0.8)
#   点火延迟: 1.251e-04 s
# 计算进度: 7/425 (T=1100K, P=0.9atm, phi=0.9)
#   点火延迟: 1.239e-04 s
# 计算进度: 8/425 (T=1100K, P=0.9atm, phi=1.0)
#   点火延迟: 1.218e-04 s
# 计算进度: 9/425 (T=1100K, P=0.9atm, phi=1.1)
#   点火延迟: 1.192e-04 s
# 计算进度: 10/425 (T=1100K, P=0.9atm, phi=1.2)
#   点火延迟: 1.194e-04 s
# 计算进度: 11/425 (T=1100K, P=1.0atm, phi=0.8)
#   点火延迟: 1.115e-04 s
# 计算进度: 12/425 (T=1100K, P=1.0atm, phi=0.9)
#   点火延迟: 1.103e-04 s
# 计算进度: 13/425 (T=1100K, P=1.0atm, phi=1.0)
#   点火延迟: 1.092e-04 s
# 计算进度: 14/425 (T=1100K, P=1.0atm, phi=1.1)
#   点火延迟: 1.080e-04 s
# 计算进度: 15/425 (T=1100K, P=1.0atm, phi=1.2)
#   点火延迟: 1.068e-04 s
# 计算进度: 16/425 (T=1100K, P=1.1atm, phi=0.8)
#   点火延迟: 1.005e-04 s
# 计算进度: 17/425 (T=1100K, P=1.1atm, phi=0.9)
#   点火延迟: 1.010e-04 s
# 计算进度: 18/425 (T=1100K, P=1.1atm, phi=1.0)
#   点火延迟: 9.794e-05 s
# 计算进度: 19/425 (T=1100K, P=1.1atm, phi=1.1)
#   点火延迟: 9.854e-05 s
# 计算进度: 20/425 (T=1100K, P=1.1atm, phi=1.2)
#   点火延迟: 9.735e-05 s
# 计算进度: 21/425 (T=1100K, P=1.2atm, phi=0.8)
#   点火延迟: 9.176e-05 s
# 计算进度: 22/425 (T=1100K, P=1.2atm, phi=0.9)
#   点火延迟: 9.224e-05 s
# 计算进度: 23/425 (T=1100K, P=1.2atm, phi=1.0)
#   点火延迟: 9.134e-05 s
# 计算进度: 24/425 (T=1100K, P=1.2atm, phi=1.1)
#   点火延迟: 9.008e-05 s
# 计算进度: 25/425 (T=1100K, P=1.2atm, phi=1.2)
#   点火延迟: 8.907e-05 s
# 计算进度: 26/425 (T=1125K, P=0.8atm, phi=0.8)
#   点火延迟: 1.270e-04 s
# 计算进度: 27/425 (T=1125K, P=0.8atm, phi=0.9)
#   点火延迟: 1.251e-04 s
# 计算进度: 28/425 (T=1125K, P=0.8atm, phi=1.0)
#   点火延迟: 1.226e-04 s
# 计算进度: 29/425 (T=1125K, P=0.8atm, phi=1.1)
#   点火延迟: 1.203e-04 s
# 计算进度: 30/425 (T=1125K, P=0.8atm, phi=1.2)
#   点火延迟: 1.171e-04 s
# 计算进度: 31/425 (T=1125K, P=0.9atm, phi=0.8)
#   点火延迟: 1.116e-04 s
# 计算进度: 32/425 (T=1125K, P=0.9atm, phi=0.9)
#   点火延迟: 1.093e-04 s
# 计算进度: 33/425 (T=1125K, P=0.9atm, phi=1.0)
#   点火延迟: 1.070e-04 s
# 计算进度: 34/425 (T=1125K, P=0.9atm, phi=1.1)
#   点火延迟: 1.053e-04 s
# 计算进度: 35/425 (T=1125K, P=0.9atm, phi=1.2)
#   点火延迟: 1.021e-04 s
# 计算进度: 36/425 (T=1125K, P=1.0atm, phi=0.8)
#   点火延迟: 9.774e-05 s
# 计算进度: 37/425 (T=1125K, P=1.0atm, phi=0.9)
#   点火延迟: 9.613e-05 s
# 计算进度: 38/425 (T=1125K, P=1.0atm, phi=1.0)
#   点火延迟: 9.345e-05 s
# 计算进度: 39/425 (T=1125K, P=1.0atm, phi=1.1)
#   点火延迟: 9.321e-05 s
# 计算进度: 40/425 (T=1125K, P=1.0atm, phi=1.2)
#   点火延迟: 9.138e-05 s
# 计算进度: 41/425 (T=1125K, P=1.1atm, phi=0.8)
#   点火延迟: 8.757e-05 s
# 计算进度: 42/425 (T=1125K, P=1.1atm, phi=0.9)
#   点火延迟: 8.624e-05 s
# 计算进度: 43/425 (T=1125K, P=1.1atm, phi=1.0)
#   点火延迟: 8.541e-05 s
# 计算进度: 44/425 (T=1125K, P=1.1atm, phi=1.1)
#   点火延迟: 8.333e-05 s
# 计算进度: 45/425 (T=1125K, P=1.1atm, phi=1.2)
#   点火延迟: 8.381e-05 s
# 计算进度: 46/425 (T=1125K, P=1.2atm, phi=0.8)
#   点火延迟: 7.944e-05 s
# 计算进度: 47/425 (T=1125K, P=1.2atm, phi=0.9)
#   点火延迟: 7.945e-05 s
# 计算进度: 48/425 (T=1125K, P=1.2atm, phi=1.0)
#   点火延迟: 7.855e-05 s
# 计算进度: 49/425 (T=1125K, P=1.2atm, phi=1.1)
#   点火延迟: 7.607e-05 s
# 计算进度: 50/425 (T=1125K, P=1.2atm, phi=1.2)
#   点火延迟: 7.652e-05 s
# 计算进度: 51/425 (T=1150K, P=0.8atm, phi=0.8)
#   点火延迟: 1.158e-04 s
# 计算进度: 52/425 (T=1150K, P=0.8atm, phi=0.9)
#   点火延迟: 1.139e-04 s
# 计算进度: 53/425 (T=1150K, P=0.8atm, phi=1.0)
#   点火延迟: 1.104e-04 s
# 计算进度: 54/425 (T=1150K, P=0.8atm, phi=1.1)
#   点火延迟: 1.060e-04 s
# 计算进度: 55/425 (T=1150K, P=0.8atm, phi=1.2)
#   点火延迟: 1.049e-04 s
# 计算进度: 56/425 (T=1150K, P=0.9atm, phi=0.8)
#   点火延迟: 1.012e-04 s
# 计算进度: 57/425 (T=1150K, P=0.9atm, phi=0.9)
#   点火延迟: 9.677e-05 s
# 计算进度: 58/425 (T=1150K, P=0.9atm, phi=1.0)
#   点火延迟: 9.403e-05 s
# 计算进度: 59/425 (T=1150K, P=0.9atm, phi=1.1)
#   点火延迟: 9.252e-05 s
# 计算进度: 60/425 (T=1150K, P=0.9atm, phi=1.2)
#   点火延迟: 9.028e-05 s
# 计算进度: 61/425 (T=1150K, P=1.0atm, phi=0.8)
#   点火延迟: 8.585e-05 s
# 计算进度: 62/425 (T=1150K, P=1.0atm, phi=0.9)
#   点火延迟: 8.714e-05 s
# 计算进度: 63/425 (T=1150K, P=1.0atm, phi=1.0)
#   点火延迟: 8.427e-05 s
# 计算进度: 64/425 (T=1150K, P=1.0atm, phi=1.1)
#   点火延迟: 8.303e-05 s
# 计算进度: 65/425 (T=1150K, P=1.0atm, phi=1.2)
#   点火延迟: 8.104e-05 s
# 计算进度: 66/425 (T=1150K, P=1.1atm, phi=0.8)
#   点火延迟: 7.712e-05 s
# 计算进度: 67/425 (T=1150K, P=1.1atm, phi=0.9)
#   点火延迟: 7.669e-05 s
# 计算进度: 68/425 (T=1150K, P=1.1atm, phi=1.0)
#   点火延迟: 7.488e-05 s
# 计算进度: 69/425 (T=1150K, P=1.1atm, phi=1.1)
#   点火延迟: 7.334e-05 s
# 计算进度: 70/425 (T=1150K, P=1.1atm, phi=1.2)
#   点火延迟: 7.290e-05 s
# 计算进度: 71/425 (T=1150K, P=1.2atm, phi=0.8)
#   点火延迟: 7.083e-05 s
# 计算进度: 72/425 (T=1150K, P=1.2atm, phi=0.9)
#   点火延迟: 7.045e-05 s
# 计算进度: 73/425 (T=1150K, P=1.2atm, phi=1.0)
#   点火延迟: 6.816e-05 s
# 计算进度: 74/425 (T=1150K, P=1.2atm, phi=1.1)
#   点火延迟: 6.665e-05 s
# 计算进度: 75/425 (T=1150K, P=1.2atm, phi=1.2)
#   点火延迟: 6.510e-05 s
# 计算进度: 76/425 (T=1175K, P=0.8atm, phi=0.8)
#   点火延迟: 1.061e-04 s
# 计算进度: 77/425 (T=1175K, P=0.8atm, phi=0.9)
#   点火延迟: 1.014e-04 s
# 计算进度: 78/425 (T=1175K, P=0.8atm, phi=1.0)
#   点火延迟: 1.013e-04 s
# 计算进度: 79/425 (T=1175K, P=0.8atm, phi=1.1)
#   点火延迟: 9.652e-05 s
# 计算进度: 80/425 (T=1175K, P=0.8atm, phi=1.2)
#   点火延迟: 9.475e-05 s
# 计算进度: 81/425 (T=1175K, P=0.9atm, phi=0.8)
#   点火延迟: 9.061e-05 s
# 计算进度: 82/425 (T=1175K, P=0.9atm, phi=0.9)
#   点火延迟: 8.883e-05 s
# 计算进度: 83/425 (T=1175K, P=0.9atm, phi=1.0)
#   点火延迟: 8.773e-05 s
# 计算进度: 84/425 (T=1175K, P=0.9atm, phi=1.1)
#   点火延迟: 8.439e-05 s
# 计算进度: 85/425 (T=1175K, P=0.9atm, phi=1.2)
#   点火延迟: 8.182e-05 s
# 计算进度: 86/425 (T=1175K, P=1.0atm, phi=0.8)
#   点火延迟: 8.004e-05 s
# 计算进度: 87/425 (T=1175K, P=1.0atm, phi=0.9)
#   点火延迟: 7.836e-05 s
# 计算进度: 88/425 (T=1175K, P=1.0atm, phi=1.0)
#   点火延迟: 7.552e-05 s
# 计算进度: 89/425 (T=1175K, P=1.0atm, phi=1.1)
#   点火延迟: 7.321e-05 s
# 计算进度: 90/425 (T=1175K, P=1.0atm, phi=1.2)
#   点火延迟: 7.132e-05 s
# 计算进度: 91/425 (T=1175K, P=1.1atm, phi=0.8)
#   点火延迟: 6.957e-05 s
# 计算进度: 92/425 (T=1175K, P=1.1atm, phi=0.9)
#   点火延迟: 6.876e-05 s
# 计算进度: 93/425 (T=1175K, P=1.1atm, phi=1.0)
#   点火延迟: 6.738e-05 s
# 计算进度: 94/425 (T=1175K, P=1.1atm, phi=1.1)
#   点火延迟: 6.679e-05 s
# 计算进度: 95/425 (T=1175K, P=1.1atm, phi=1.2)
#   点火延迟: 6.391e-05 s
# 计算进度: 96/425 (T=1175K, P=1.2atm, phi=0.8)
#   点火延迟: 6.333e-05 s
# 计算进度: 97/425 (T=1175K, P=1.2atm, phi=0.9)
#   点火延迟: 6.182e-05 s
# 计算进度: 98/425 (T=1175K, P=1.2atm, phi=1.0)
#   点火延迟: 6.163e-05 s
# 计算进度: 99/425 (T=1175K, P=1.2atm, phi=1.1)
#   点火延迟: 6.014e-05 s
# 计算进度: 100/425 (T=1175K, P=1.2atm, phi=1.2)
#   点火延迟: 5.924e-05 s
# 计算进度: 101/425 (T=1200K, P=0.8atm, phi=0.8)
#   点火延迟: 9.696e-05 s
# 计算进度: 102/425 (T=1200K, P=0.8atm, phi=0.9)
#   点火延迟: 9.358e-05 s
# 计算进度: 103/425 (T=1200K, P=0.8atm, phi=1.0)
#   点火延迟: 9.330e-05 s
# 计算进度: 104/425 (T=1200K, P=0.8atm, phi=1.1)
#   点火延迟: 8.893e-05 s
# 计算进度: 105/425 (T=1200K, P=0.8atm, phi=1.2)
#   点火延迟: 8.484e-05 s
# 计算进度: 106/425 (T=1200K, P=0.9atm, phi=0.8)
#   点火延迟: 8.486e-05 s
# 计算进度: 107/425 (T=1200K, P=0.9atm, phi=0.9)
#   点火延迟: 8.250e-05 s
# 计算进度: 108/425 (T=1200K, P=0.9atm, phi=1.0)
#   点火延迟: 7.912e-05 s
# 计算进度: 109/425 (T=1200K, P=0.9atm, phi=1.1)
#   点火延迟: 7.656e-05 s
# 计算进度: 110/425 (T=1200K, P=0.9atm, phi=1.2)
#   点火延迟: 7.449e-05 s
# 计算进度: 111/425 (T=1200K, P=1.0atm, phi=0.8)
#   点火延迟: 7.180e-05 s
# 计算进度: 112/425 (T=1200K, P=1.0atm, phi=0.9)
#   点火延迟: 7.219e-05 s
# 计算进度: 113/425 (T=1200K, P=1.0atm, phi=1.0)
#   点火延迟: 6.937e-05 s
# 计算进度: 114/425 (T=1200K, P=1.0atm, phi=1.1)
#   点火延迟: 6.594e-05 s
# 计算进度: 115/425 (T=1200K, P=1.0atm, phi=1.2)
#   点火延迟: 6.418e-05 s
# 计算进度: 116/425 (T=1200K, P=1.1atm, phi=0.8)
#   点火延迟: 6.415e-05 s
# 计算进度: 117/425 (T=1200K, P=1.1atm, phi=0.9)
#   点火延迟: 6.228e-05 s
# 计算进度: 118/425 (T=1200K, P=1.1atm, phi=1.0)
#   点火延迟: 6.053e-05 s
# 计算进度: 119/425 (T=1200K, P=1.1atm, phi=1.1)
#   点火延迟: 6.034e-05 s
# 计算进度: 120/425 (T=1200K, P=1.1atm, phi=1.2)
#   点火延迟: 5.895e-05 s
# 计算进度: 121/425 (T=1200K, P=1.2atm, phi=0.8)
#   点火延迟: 5.908e-05 s
# 计算进度: 122/425 (T=1200K, P=1.2atm, phi=0.9)
#   点火延迟: 5.677e-05 s
# 计算进度: 123/425 (T=1200K, P=1.2atm, phi=1.0)
#   点火延迟: 5.396e-05 s
# 计算进度: 124/425 (T=1200K, P=1.2atm, phi=1.1)
#   点火延迟: 5.334e-05 s
# 计算进度: 125/425 (T=1200K, P=1.2atm, phi=1.2)
#   点火延迟: 5.145e-05 s
# 计算进度: 126/425 (T=1225K, P=0.8atm, phi=0.8)
#   点火延迟: 9.258e-05 s
# 计算进度: 127/425 (T=1225K, P=0.8atm, phi=0.9)
#   点火延迟: 8.813e-05 s
# 计算进度: 128/425 (T=1225K, P=0.8atm, phi=1.0)
#   点火延迟: 8.480e-05 s
# 计算进度: 129/425 (T=1225K, P=0.8atm, phi=1.1)
#   点火延迟: 8.172e-05 s
# 计算进度: 130/425 (T=1225K, P=0.8atm, phi=1.2)
#   点火延迟: 8.000e-05 s
# 计算进度: 131/425 (T=1225K, P=0.9atm, phi=0.8)
#   点火延迟: 8.003e-05 s
# 计算进度: 132/425 (T=1225K, P=0.9atm, phi=0.9)
#   点火延迟: 7.762e-05 s
# 计算进度: 133/425 (T=1225K, P=0.9atm, phi=1.0)
#   点火延迟: 7.273e-05 s
# 计算进度: 134/425 (T=1225K, P=0.9atm, phi=1.1)
#   点火延迟: 7.045e-05 s
# 计算进度: 135/425 (T=1225K, P=0.9atm, phi=1.2)
#   点火延迟: 6.831e-05 s
# 计算进度: 136/425 (T=1225K, P=1.0atm, phi=0.8)
#   点火延迟: 6.875e-05 s
# 计算进度: 137/425 (T=1225K, P=1.0atm, phi=0.9)
#   点火延迟: 6.759e-05 s
# 计算进度: 138/425 (T=1225K, P=1.0atm, phi=1.0)
#   点火延迟: 6.384e-05 s
# 计算进度: 139/425 (T=1225K, P=1.0atm, phi=1.1)
#   点火延迟: 6.199e-05 s
# 计算进度: 140/425 (T=1225K, P=1.0atm, phi=1.2)
#   点火延迟: 5.819e-05 s
# 计算进度: 141/425 (T=1225K, P=1.1atm, phi=0.8)
#   点火延迟: 5.991e-05 s
# 计算进度: 142/425 (T=1225K, P=1.1atm, phi=0.9)
#   点火延迟: 5.867e-05 s
# 计算进度: 143/425 (T=1225K, P=1.1atm, phi=1.0)
#   点火延迟: 5.734e-05 s
# 计算进度: 144/425 (T=1225K, P=1.1atm, phi=1.1)
#   点火延迟: 5.409e-05 s
# 计算进度: 145/425 (T=1225K, P=1.1atm, phi=1.2)
#   点火延迟: 5.365e-05 s
# 计算进度: 146/425 (T=1225K, P=1.2atm, phi=0.8)
#   点火延迟: 5.365e-05 s
# 计算进度: 147/425 (T=1225K, P=1.2atm, phi=0.9)
#   点火延迟: 5.281e-05 s
# 计算进度: 148/425 (T=1225K, P=1.2atm, phi=1.0)
#   点火延迟: 4.931e-05 s
# 计算进度: 149/425 (T=1225K, P=1.2atm, phi=1.1)
#   点火延迟: 4.887e-05 s
# 计算进度: 150/425 (T=1225K, P=1.2atm, phi=1.2)
#   点火延迟: 4.739e-05 s
# 计算进度: 151/425 (T=1250K, P=0.8atm, phi=0.8)
#   点火延迟: 8.731e-05 s
# 计算进度: 152/425 (T=1250K, P=0.8atm, phi=0.9)
#   点火延迟: 8.559e-05 s
# 计算进度: 153/425 (T=1250K, P=0.8atm, phi=1.0)
#   点火延迟: 8.045e-05 s
# 计算进度: 154/425 (T=1250K, P=0.8atm, phi=1.1)
#   点火延迟: 7.963e-05 s
# 计算进度: 155/425 (T=1250K, P=0.8atm, phi=1.2)
#   点火延迟: 7.207e-05 s
# 计算进度: 156/425 (T=1250K, P=0.9atm, phi=0.8)
#   点火延迟: 7.486e-05 s
# 计算进度: 157/425 (T=1250K, P=0.9atm, phi=0.9)
#   点火延迟: 6.997e-05 s
# 计算进度: 158/425 (T=1250K, P=0.9atm, phi=1.0)
#   点火延迟: 6.743e-05 s
# 计算进度: 159/425 (T=1250K, P=0.9atm, phi=1.1)
#   点火延迟: 6.581e-05 s
# 计算进度: 160/425 (T=1250K, P=0.9atm, phi=1.2)
#   点火延迟: 6.292e-05 s
# 计算进度: 161/425 (T=1250K, P=1.0atm, phi=0.8)
#   点火延迟: 6.339e-05 s
# 计算进度: 162/425 (T=1250K, P=1.0atm, phi=0.9)
#   点火延迟: 6.149e-05 s
# 计算进度: 163/425 (T=1250K, P=1.0atm, phi=1.0)
#   点火延迟: 5.865e-05 s
# 计算进度: 164/425 (T=1250K, P=1.0atm, phi=1.1)
#   点火延迟: 5.507e-05 s
# 计算进度: 165/425 (T=1250K, P=1.0atm, phi=1.2)
#   点火延迟: 5.557e-05 s
# 计算进度: 166/425 (T=1250K, P=1.1atm, phi=0.8)
#   点火延迟: 5.615e-05 s
# 计算进度: 167/425 (T=1250K, P=1.1atm, phi=0.9)
#   点火延迟: 5.382e-05 s
# 计算进度: 168/425 (T=1250K, P=1.1atm, phi=1.0)
#   点火延迟: 5.291e-05 s
# 计算进度: 169/425 (T=1250K, P=1.1atm, phi=1.1)
#   点火延迟: 5.061e-05 s
# 计算进度: 170/425 (T=1250K, P=1.1atm, phi=1.2)
#   点火延迟: 4.860e-05 s
# 计算进度: 171/425 (T=1250K, P=1.2atm, phi=0.8)
#   点火延迟: 4.853e-05 s
# 计算进度: 172/425 (T=1250K, P=1.2atm, phi=0.9)
#   点火延迟: 4.821e-05 s
# 计算进度: 173/425 (T=1250K, P=1.2atm, phi=1.0)
#   点火延迟: 4.750e-05 s
# 计算进度: 174/425 (T=1250K, P=1.2atm, phi=1.1)
#   点火延迟: 4.428e-05 s
# 计算进度: 175/425 (T=1250K, P=1.2atm, phi=1.2)
#   点火延迟: 4.336e-05 s
# 计算进度: 176/425 (T=1275K, P=0.8atm, phi=0.8)
#   点火延迟: 8.569e-05 s
# 计算进度: 177/425 (T=1275K, P=0.8atm, phi=0.9)
#   点火延迟: 8.202e-05 s
# 计算进度: 178/425 (T=1275K, P=0.8atm, phi=1.0)
#   点火延迟: 7.661e-05 s
# 计算进度: 179/425 (T=1275K, P=0.8atm, phi=1.1)
#   点火延迟: 7.366e-05 s
# 计算进度: 180/425 (T=1275K, P=0.8atm, phi=1.2)
#   点火延迟: 7.073e-05 s
# 计算进度: 181/425 (T=1275K, P=0.9atm, phi=0.8)
#   点火延迟: 7.124e-05 s
# 计算进度: 182/425 (T=1275K, P=0.9atm, phi=0.9)
#   点火延迟: 6.700e-05 s
# 计算进度: 183/425 (T=1275K, P=0.9atm, phi=1.0)
#   点火延迟: 6.572e-05 s
# 计算进度: 184/425 (T=1275K, P=0.9atm, phi=1.1)
#   点火延迟: 6.058e-05 s
# 计算进度: 185/425 (T=1275K, P=0.9atm, phi=1.2)
#   点火延迟: 6.032e-05 s
# 计算进度: 186/425 (T=1275K, P=1.0atm, phi=0.8)
#   点火延迟: 6.070e-05 s
# 计算进度: 187/425 (T=1275K, P=1.0atm, phi=0.9)
#   点火延迟: 5.650e-05 s
# 计算进度: 188/425 (T=1275K, P=1.0atm, phi=1.0)
#   点火延迟: 5.563e-05 s
# 计算进度: 189/425 (T=1275K, P=1.0atm, phi=1.1)
#   点火延迟: 5.338e-05 s
# 计算进度: 190/425 (T=1275K, P=1.0atm, phi=1.2)
#   点火延迟: 5.000e-05 s
# 计算进度: 191/425 (T=1275K, P=1.1atm, phi=0.8)
#   点火延迟: 5.154e-05 s
# 计算进度: 192/425 (T=1275K, P=1.1atm, phi=0.9)
#   点火延迟: 5.227e-05 s
# 计算进度: 193/425 (T=1275K, P=1.1atm, phi=1.0)
#   点火延迟: 5.042e-05 s
# 计算进度: 194/425 (T=1275K, P=1.1atm, phi=1.1)
#   点火延迟: 4.593e-05 s
# 计算进度: 195/425 (T=1275K, P=1.1atm, phi=1.2)
#   点火延迟: 4.465e-05 s
# 计算进度: 196/425 (T=1275K, P=1.2atm, phi=0.8)
#   点火延迟: 4.591e-05 s
# 计算进度: 197/425 (T=1275K, P=1.2atm, phi=0.9)
#   点火延迟: 4.617e-05 s
# 计算进度: 198/425 (T=1275K, P=1.2atm, phi=1.0)
#   点火延迟: 4.427e-05 s
# 计算进度: 199/425 (T=1275K, P=1.2atm, phi=1.1)
#   点火延迟: 4.116e-05 s
# 计算进度: 200/425 (T=1275K, P=1.2atm, phi=1.2)
#   点火延迟: 4.077e-05 s
# 计算进度: 201/425 (T=1300K, P=0.8atm, phi=0.8)
#   点火延迟: 7.834e-05 s
# 计算进度: 202/425 (T=1300K, P=0.8atm, phi=0.9)
#   点火延迟: 7.808e-05 s
# 计算进度: 203/425 (T=1300K, P=0.8atm, phi=1.0)
#   点火延迟: 7.370e-05 s
# 计算进度: 204/425 (T=1300K, P=0.8atm, phi=1.1)
#   点火延迟: 7.114e-05 s
# 计算进度: 205/425 (T=1300K, P=0.8atm, phi=1.2)
#   点火延迟: 6.653e-05 s
# 计算进度: 206/425 (T=1300K, P=0.9atm, phi=0.8)
#   点火延迟: 6.880e-05 s
# 计算进度: 207/425 (T=1300K, P=0.9atm, phi=0.9)
#   点火延迟: 6.638e-05 s
# 计算进度: 208/425 (T=1300K, P=0.9atm, phi=1.0)
#   点火延迟: 6.341e-05 s
# 计算进度: 209/425 (T=1300K, P=0.9atm, phi=1.1)
#   点火延迟: 6.056e-05 s
# 计算进度: 210/425 (T=1300K, P=0.9atm, phi=1.2)
#   点火延迟: 5.764e-05 s
# 计算进度: 211/425 (T=1300K, P=1.0atm, phi=0.8)
#   点火延迟: 5.708e-05 s
# 计算进度: 212/425 (T=1300K, P=1.0atm, phi=0.9)
#   点火延迟: 5.507e-05 s
# 计算进度: 213/425 (T=1300K, P=1.0atm, phi=1.0)
#   点火延迟: 5.286e-05 s
# 计算进度: 214/425 (T=1300K, P=1.0atm, phi=1.1)
#   点火延迟: 4.973e-05 s
# 计算进度: 215/425 (T=1300K, P=1.0atm, phi=1.2)
#   点火延迟: 4.663e-05 s
# 计算进度: 216/425 (T=1300K, P=1.1atm, phi=0.8)
#   点火延迟: 5.038e-05 s
# 计算进度: 217/425 (T=1300K, P=1.1atm, phi=0.9)
#   点火延迟: 4.913e-05 s
# 计算进度: 218/425 (T=1300K, P=1.1atm, phi=1.0)
#   点火延迟: 4.559e-05 s
# 计算进度: 219/425 (T=1300K, P=1.1atm, phi=1.1)
#   点火延迟: 4.354e-05 s
# 计算进度: 220/425 (T=1300K, P=1.1atm, phi=1.2)
#   点火延迟: 4.095e-05 s
# 计算进度: 221/425 (T=1300K, P=1.2atm, phi=0.8)
#   点火延迟: 4.371e-05 s
# 计算进度: 222/425 (T=1300K, P=1.2atm, phi=0.9)
#   点火延迟: 4.309e-05 s
# 计算进度: 223/425 (T=1300K, P=1.2atm, phi=1.0)
#   点火延迟: 4.189e-05 s
# 计算进度: 224/425 (T=1300K, P=1.2atm, phi=1.1)
#   点火延迟: 4.041e-05 s
# 计算进度: 225/425 (T=1300K, P=1.2atm, phi=1.2)
#   点火延迟: 3.794e-05 s
# 计算进度: 226/425 (T=1325K, P=0.8atm, phi=0.8)
#   点火延迟: 8.038e-05 s
# 计算进度: 227/425 (T=1325K, P=0.8atm, phi=0.9)
#   点火延迟: 7.306e-05 s
# 计算进度: 228/425 (T=1325K, P=0.8atm, phi=1.0)
#   点火延迟: 6.875e-05 s
# 计算进度: 229/425 (T=1325K, P=0.8atm, phi=1.1)
#   点火延迟: 6.558e-05 s
# 计算进度: 230/425 (T=1325K, P=0.8atm, phi=1.2)
#   点火延迟: 6.224e-05 s
# 计算进度: 231/425 (T=1325K, P=0.9atm, phi=0.8)
#   点火延迟: 6.542e-05 s
# 计算进度: 232/425 (T=1325K, P=0.9atm, phi=0.9)
#   点火延迟: 6.239e-05 s
# 计算进度: 233/425 (T=1325K, P=0.9atm, phi=1.0)
#   点火延迟: 6.109e-05 s
# 计算进度: 234/425 (T=1325K, P=0.9atm, phi=1.1)
#   点火延迟: 5.402e-05 s
# 计算进度: 235/425 (T=1325K, P=0.9atm, phi=1.2)
#   点火延迟: 5.309e-05 s
# 计算进度: 236/425 (T=1325K, P=1.0atm, phi=0.8)
#   点火延迟: 5.403e-05 s
# 计算进度: 237/425 (T=1325K, P=1.0atm, phi=0.9)
#   点火延迟: 5.292e-05 s
# 计算进度: 238/425 (T=1325K, P=1.0atm, phi=1.0)
#   点火延迟: 5.017e-05 s
# 计算进度: 239/425 (T=1325K, P=1.0atm, phi=1.1)
#   点火延迟: 4.754e-05 s
# 计算进度: 240/425 (T=1325K, P=1.0atm, phi=1.2)
#   点火延迟: 4.560e-05 s
# 计算进度: 241/425 (T=1325K, P=1.1atm, phi=0.8)
#   点火延迟: 4.860e-05 s
# 计算进度: 242/425 (T=1325K, P=1.1atm, phi=0.9)
#   点火延迟: 4.772e-05 s
# 计算进度: 243/425 (T=1325K, P=1.1atm, phi=1.0)
#   点火延迟: 4.337e-05 s
# 计算进度: 244/425 (T=1325K, P=1.1atm, phi=1.1)
#   点火延迟: 4.123e-05 s
# 计算进度: 245/425 (T=1325K, P=1.1atm, phi=1.2)
#   点火延迟: 4.064e-05 s
# 计算进度: 246/425 (T=1325K, P=1.2atm, phi=0.8)
#   点火延迟: 4.251e-05 s
# 计算进度: 247/425 (T=1325K, P=1.2atm, phi=0.9)
#   点火延迟: 4.170e-05 s
# 计算进度: 248/425 (T=1325K, P=1.2atm, phi=1.0)
#   点火延迟: 3.935e-05 s
# 计算进度: 249/425 (T=1325K, P=1.2atm, phi=1.1)
#   点火延迟: 3.629e-05 s
# 计算进度: 250/425 (T=1325K, P=1.2atm, phi=1.2)
#   点火延迟: 3.449e-05 s
# 计算进度: 251/425 (T=1350K, P=0.8atm, phi=0.8)
#   点火延迟: 7.794e-05 s
# 计算进度: 252/425 (T=1350K, P=0.8atm, phi=0.9)
#   点火延迟: 7.048e-05 s
# 计算进度: 253/425 (T=1350K, P=0.8atm, phi=1.0)
#   点火延迟: 6.725e-05 s
# 计算进度: 254/425 (T=1350K, P=0.8atm, phi=1.1)
#   点火延迟: 6.537e-05 s
# 计算进度: 255/425 (T=1350K, P=0.8atm, phi=1.2)
#   点火延迟: 6.242e-05 s
# 计算进度: 256/425 (T=1350K, P=0.9atm, phi=0.8)
#   点火延迟: 6.236e-05 s
# 计算进度: 257/425 (T=1350K, P=0.9atm, phi=0.9)
#   点火延迟: 6.390e-05 s
# 计算进度: 258/425 (T=1350K, P=0.9atm, phi=1.0)
#   点火延迟: 5.572e-05 s
# 计算进度: 259/425 (T=1350K, P=0.9atm, phi=1.1)
#   点火延迟: 5.313e-05 s
# 计算进度: 260/425 (T=1350K, P=0.9atm, phi=1.2)
#   点火延迟: 5.091e-05 s
# 计算进度: 261/425 (T=1350K, P=1.0atm, phi=0.8)
#   点火延迟: 5.567e-05 s
# 计算进度: 262/425 (T=1350K, P=1.0atm, phi=0.9)
#   点火延迟: 5.184e-05 s
# 计算进度: 263/425 (T=1350K, P=1.0atm, phi=1.0)
#   点火延迟: 4.867e-05 s
# 计算进度: 264/425 (T=1350K, P=1.0atm, phi=1.1)
#   点火延迟: 4.487e-05 s
# 计算进度: 265/425 (T=1350K, P=1.0atm, phi=1.2)
#   点火延迟: 4.447e-05 s
# 计算进度: 266/425 (T=1350K, P=1.1atm, phi=0.8)
#   点火延迟: 4.781e-05 s
# 计算进度: 267/425 (T=1350K, P=1.1atm, phi=0.9)
#   点火延迟: 4.455e-05 s
# 计算进度: 268/425 (T=1350K, P=1.1atm, phi=1.0)
#   点火延迟: 4.165e-05 s
# 计算进度: 269/425 (T=1350K, P=1.1atm, phi=1.1)
#   点火延迟: 3.982e-05 s
# 计算进度: 270/425 (T=1350K, P=1.1atm, phi=1.2)
#   点火延迟: 3.841e-05 s
# 计算进度: 271/425 (T=1350K, P=1.2atm, phi=0.8)
#   点火延迟: 4.089e-05 s
# 计算进度: 272/425 (T=1350K, P=1.2atm, phi=0.9)
#   点火延迟: 3.812e-05 s
# 计算进度: 273/425 (T=1350K, P=1.2atm, phi=1.0)
#   点火延迟: 3.857e-05 s
# 计算进度: 274/425 (T=1350K, P=1.2atm, phi=1.1)
#   点火延迟: 3.405e-05 s
# 计算进度: 275/425 (T=1350K, P=1.2atm, phi=1.2)
#   点火延迟: 3.303e-05 s
# 计算进度: 276/425 (T=1375K, P=0.8atm, phi=0.8)
#   点火延迟: 7.478e-05 s
# 计算进度: 277/425 (T=1375K, P=0.8atm, phi=0.9)
#   点火延迟: 7.081e-05 s
# 计算进度: 278/425 (T=1375K, P=0.8atm, phi=1.0)
#   点火延迟: 6.489e-05 s
# 计算进度: 279/425 (T=1375K, P=0.8atm, phi=1.1)
#   点火延迟: 6.027e-05 s
# 计算进度: 280/425 (T=1375K, P=0.8atm, phi=1.2)
#   点火延迟: 5.909e-05 s
# 计算进度: 281/425 (T=1375K, P=0.9atm, phi=0.8)
#   点火延迟: 6.311e-05 s
# 计算进度: 282/425 (T=1375K, P=0.9atm, phi=0.9)
#   点火延迟: 6.047e-05 s
# 计算进度: 283/425 (T=1375K, P=0.9atm, phi=1.0)
#   点火延迟: 5.632e-05 s
# 计算进度: 284/425 (T=1375K, P=0.9atm, phi=1.1)
#   点火延迟: 5.104e-05 s
# 计算进度: 285/425 (T=1375K, P=0.9atm, phi=1.2)
#   点火延迟: 5.037e-05 s
# 计算进度: 286/425 (T=1375K, P=1.0atm, phi=0.8)
#   点火延迟: 5.175e-05 s
# 计算进度: 287/425 (T=1375K, P=1.0atm, phi=0.9)
#   点火延迟: 4.865e-05 s
# 计算进度: 288/425 (T=1375K, P=1.0atm, phi=1.0)
#   点火延迟: 4.579e-05 s
# 计算进度: 289/425 (T=1375K, P=1.0atm, phi=1.1)
#   点火延迟: 4.559e-05 s
# 计算进度: 290/425 (T=1375K, P=1.0atm, phi=1.2)
#   点火延迟: 4.283e-05 s
# 计算进度: 291/425 (T=1375K, P=1.1atm, phi=0.8)
#   点火延迟: 4.510e-05 s
# 计算进度: 292/425 (T=1375K, P=1.1atm, phi=0.9)
#   点火延迟: 4.273e-05 s
# 计算进度: 293/425 (T=1375K, P=1.1atm, phi=1.0)
#   点火延迟: 4.009e-05 s
# 计算进度: 294/425 (T=1375K, P=1.1atm, phi=1.1)
#   点火延迟: 3.774e-05 s
# 计算进度: 295/425 (T=1375K, P=1.1atm, phi=1.2)
#   点火延迟: 3.589e-05 s
# 计算进度: 296/425 (T=1375K, P=1.2atm, phi=0.8)
#   点火延迟: 3.944e-05 s
# 计算进度: 297/425 (T=1375K, P=1.2atm, phi=0.9)
#   点火延迟: 3.811e-05 s
# 计算进度: 298/425 (T=1375K, P=1.2atm, phi=1.0)
#   点火延迟: 3.510e-05 s
# 计算进度: 299/425 (T=1375K, P=1.2atm, phi=1.1)
#   点火延迟: 3.348e-05 s
# 计算进度: 300/425 (T=1375K, P=1.2atm, phi=1.2)
#   点火延迟: 3.209e-05 s
# 计算进度: 301/425 (T=1400K, P=0.8atm, phi=0.8)
#   点火延迟: 7.292e-05 s
# 计算进度: 302/425 (T=1400K, P=0.8atm, phi=0.9)
#   点火延迟: 7.230e-05 s
# 计算进度: 303/425 (T=1400K, P=0.8atm, phi=1.0)
#   点火延迟: 6.727e-05 s
# 计算进度: 304/425 (T=1400K, P=0.8atm, phi=1.1)
#   点火延迟: 6.122e-05 s
# 计算进度: 305/425 (T=1400K, P=0.8atm, phi=1.2)
#   点火延迟: 5.694e-05 s
# 计算进度: 306/425 (T=1400K, P=0.9atm, phi=0.8)
#   点火延迟: 6.108e-05 s
# 计算进度: 307/425 (T=1400K, P=0.9atm, phi=0.9)
#   点火延迟: 5.762e-05 s
# 计算进度: 308/425 (T=1400K, P=0.9atm, phi=1.0)
#   点火延迟: 5.420e-05 s
# 计算进度: 309/425 (T=1400K, P=0.9atm, phi=1.1)
#   点火延迟: 5.227e-05 s
# 计算进度: 310/425 (T=1400K, P=0.9atm, phi=1.2)
#   点火延迟: 4.919e-05 s
# 计算进度: 311/425 (T=1400K, P=1.0atm, phi=0.8)
#   点火延迟: 5.361e-05 s
# 计算进度: 312/425 (T=1400K, P=1.0atm, phi=0.9)
#   点火延迟: 5.117e-05 s
# 计算进度: 313/425 (T=1400K, P=1.0atm, phi=1.0)
#   点火延迟: 4.674e-05 s
# 计算进度: 314/425 (T=1400K, P=1.0atm, phi=1.1)
#   点火延迟: 4.255e-05 s
# 计算进度: 315/425 (T=1400K, P=1.0atm, phi=1.2)
#   点火延迟: 3.937e-05 s
# 计算进度: 316/425 (T=1400K, P=1.1atm, phi=0.8)
#   点火延迟: 4.237e-05 s
# 计算进度: 317/425 (T=1400K, P=1.1atm, phi=0.9)
#   点火延迟: 4.293e-05 s
# 计算进度: 318/425 (T=1400K, P=1.1atm, phi=1.0)
#   点火延迟: 3.949e-05 s
# 计算进度: 319/425 (T=1400K, P=1.1atm, phi=1.1)
#   点火延迟: 3.875e-05 s
# 计算进度: 320/425 (T=1400K, P=1.1atm, phi=1.2)
#   点火延迟: 3.429e-05 s
# 计算进度: 321/425 (T=1400K, P=1.2atm, phi=0.8)
#   点火延迟: 3.767e-05 s
# 计算进度: 322/425 (T=1400K, P=1.2atm, phi=0.9)
#   点火延迟: 3.681e-05 s
# 计算进度: 323/425 (T=1400K, P=1.2atm, phi=1.0)
#   点火延迟: 3.392e-05 s
# 计算进度: 324/425 (T=1400K, P=1.2atm, phi=1.1)
#   点火延迟: 3.229e-05 s
# 计算进度: 325/425 (T=1400K, P=1.2atm, phi=1.2)
#   点火延迟: 3.194e-05 s
# 计算进度: 326/425 (T=1425K, P=0.8atm, phi=0.8)
#   点火延迟: 7.621e-05 s
# 计算进度: 327/425 (T=1425K, P=0.8atm, phi=0.9)
#   点火延迟: 6.802e-05 s
# 计算进度: 328/425 (T=1425K, P=0.8atm, phi=1.0)
#   点火延迟: 6.369e-05 s
# 计算进度: 329/425 (T=1425K, P=0.8atm, phi=1.1)
#   点火延迟: 5.881e-05 s
# 计算进度: 330/425 (T=1425K, P=0.8atm, phi=1.2)
#   点火延迟: 5.403e-05 s
# 计算进度: 331/425 (T=1425K, P=0.9atm, phi=0.8)
#   点火延迟: 5.885e-05 s
# 计算进度: 332/425 (T=1425K, P=0.9atm, phi=0.9)
#   点火延迟: 5.976e-05 s
# 计算进度: 333/425 (T=1425K, P=0.9atm, phi=1.0)
#   点火延迟: 5.408e-05 s
# 计算进度: 334/425 (T=1425K, P=0.9atm, phi=1.1)
#   点火延迟: 5.120e-05 s
# 计算进度: 335/425 (T=1425K, P=0.9atm, phi=1.2)
#   点火延迟: 4.528e-05 s
# 计算进度: 336/425 (T=1425K, P=1.0atm, phi=0.8)
#   点火延迟: 4.919e-05 s
# 计算进度: 337/425 (T=1425K, P=1.0atm, phi=0.9)
#   点火延迟: 4.967e-05 s
# 计算进度: 338/425 (T=1425K, P=1.0atm, phi=1.0)
#   点火延迟: 4.591e-05 s
# 计算进度: 339/425 (T=1425K, P=1.0atm, phi=1.1)
#   点火延迟: 4.222e-05 s
# 计算进度: 340/425 (T=1425K, P=1.0atm, phi=1.2)
#   点火延迟: 3.842e-05 s
# 计算进度: 341/425 (T=1425K, P=1.1atm, phi=0.8)
#   点火延迟: 4.455e-05 s
# 计算进度: 342/425 (T=1425K, P=1.1atm, phi=0.9)
#   点火延迟: 4.330e-05 s
# 计算进度: 343/425 (T=1425K, P=1.1atm, phi=1.0)
#   点火延迟: 3.835e-05 s
# 计算进度: 344/425 (T=1425K, P=1.1atm, phi=1.1)
#   点火延迟: 3.676e-05 s
# 计算进度: 345/425 (T=1425K, P=1.1atm, phi=1.2)
#   点火延迟: 3.292e-05 s
# 计算进度: 346/425 (T=1425K, P=1.2atm, phi=0.8)
#   点火延迟: 3.704e-05 s
# 计算进度: 347/425 (T=1425K, P=1.2atm, phi=0.9)
#   点火延迟: 3.568e-05 s
# 计算进度: 348/425 (T=1425K, P=1.2atm, phi=1.0)
#   点火延迟: 3.355e-05 s
# 计算进度: 349/425 (T=1425K, P=1.2atm, phi=1.1)
#   点火延迟: 3.262e-05 s
# 计算进度: 350/425 (T=1425K, P=1.2atm, phi=1.2)
#   点火延迟: 2.954e-05 s
# 计算进度: 351/425 (T=1450K, P=0.8atm, phi=0.8)
#   点火延迟: 7.602e-05 s
# 计算进度: 352/425 (T=1450K, P=0.8atm, phi=0.9)
#   点火延迟: 6.758e-05 s
# 计算进度: 353/425 (T=1450K, P=0.8atm, phi=1.0)
#   点火延迟: 6.534e-05 s
# 计算进度: 354/425 (T=1450K, P=0.8atm, phi=1.1)
#   点火延迟: 6.073e-05 s
# 计算进度: 355/425 (T=1450K, P=0.8atm, phi=1.2)
#   点火延迟: 5.369e-05 s
# 计算进度: 356/425 (T=1450K, P=0.9atm, phi=0.8)
#   点火延迟: 6.217e-05 s
# 计算进度: 357/425 (T=1450K, P=0.9atm, phi=0.9)
#   点火延迟: 6.027e-05 s
# 计算进度: 358/425 (T=1450K, P=0.9atm, phi=1.0)
#   点火延迟: 5.080e-05 s
# 计算进度: 359/425 (T=1450K, P=0.9atm, phi=1.1)
#   点火延迟: 4.756e-05 s
# 计算进度: 360/425 (T=1450K, P=0.9atm, phi=1.2)
#   点火延迟: 4.455e-05 s
# 计算进度: 361/425 (T=1450K, P=1.0atm, phi=0.8)
#   点火延迟: 5.135e-05 s
# 计算进度: 362/425 (T=1450K, P=1.0atm, phi=0.9)
#   点火延迟: 4.516e-05 s
# 计算进度: 363/425 (T=1450K, P=1.0atm, phi=1.0)
#   点火延迟: 4.455e-05 s
# 计算进度: 364/425 (T=1450K, P=1.0atm, phi=1.1)
#   点火延迟: 3.968e-05 s
# 计算进度: 365/425 (T=1450K, P=1.0atm, phi=1.2)
#   点火延迟: 3.770e-05 s
# 计算进度: 366/425 (T=1450K, P=1.1atm, phi=0.8)
#   点火延迟: 4.124e-05 s
# 计算进度: 367/425 (T=1450K, P=1.1atm, phi=0.9)
#   点火延迟: 3.996e-05 s
# 计算进度: 368/425 (T=1450K, P=1.1atm, phi=1.0)
#   点火延迟: 3.864e-05 s
# 计算进度: 369/425 (T=1450K, P=1.1atm, phi=1.1)
#   点火延迟: 3.571e-05 s
# 计算进度: 370/425 (T=1450K, P=1.1atm, phi=1.2)
#   点火延迟: 3.275e-05 s
# 计算进度: 371/425 (T=1450K, P=1.2atm, phi=0.8)
#   点火延迟: 3.543e-05 s
# 计算进度: 372/425 (T=1450K, P=1.2atm, phi=0.9)
#   点火延迟: 3.471e-05 s
# 计算进度: 373/425 (T=1450K, P=1.2atm, phi=1.0)
#   点火延迟: 3.363e-05 s
# 计算进度: 374/425 (T=1450K, P=1.2atm, phi=1.1)
#   点火延迟: 3.031e-05 s
# 计算进度: 375/425 (T=1450K, P=1.2atm, phi=1.2)
#   点火延迟: 2.842e-05 s
# 计算进度: 376/425 (T=1475K, P=0.8atm, phi=0.8)
#   点火延迟: 7.563e-05 s
# 计算进度: 377/425 (T=1475K, P=0.8atm, phi=0.9)
#   点火延迟: 7.012e-05 s
# 计算进度: 378/425 (T=1475K, P=0.8atm, phi=1.0)
#   点火延迟: 6.473e-05 s
# 计算进度: 379/425 (T=1475K, P=0.8atm, phi=1.1)
#   点火延迟: 5.940e-05 s
# 计算进度: 380/425 (T=1475K, P=0.8atm, phi=1.2)
#   点火延迟: 5.519e-05 s
# 计算进度: 381/425 (T=1475K, P=0.9atm, phi=0.8)
#   点火延迟: 5.928e-05 s
# 计算进度: 382/425 (T=1475K, P=0.9atm, phi=0.9)
#   点火延迟: 5.728e-05 s
# 计算进度: 383/425 (T=1475K, P=0.9atm, phi=1.0)
#   点火延迟: 5.182e-05 s
# 计算进度: 384/425 (T=1475K, P=0.9atm, phi=1.1)
#   点火延迟: 4.898e-05 s
# 计算进度: 385/425 (T=1475K, P=0.9atm, phi=1.2)
#   点火延迟: 4.354e-05 s
# 计算进度: 386/425 (T=1475K, P=1.0atm, phi=0.8)
#   点火延迟: 5.157e-05 s
# 计算进度: 387/425 (T=1475K, P=1.0atm, phi=0.9)
#   点火延迟: 4.688e-05 s
# 计算进度: 388/425 (T=1475K, P=1.0atm, phi=1.0)
#   点火延迟: 4.237e-05 s
# 计算进度: 389/425 (T=1475K, P=1.0atm, phi=1.1)
#   点火延迟: 4.105e-05 s
# 计算进度: 390/425 (T=1475K, P=1.0atm, phi=1.2)
#   点火延迟: 3.818e-05 s
# 计算进度: 391/425 (T=1475K, P=1.1atm, phi=0.8)
#   点火延迟: 4.481e-05 s
# 计算进度: 392/425 (T=1475K, P=1.1atm, phi=0.9)
#   点火延迟: 3.927e-05 s
# 计算进度: 393/425 (T=1475K, P=1.1atm, phi=1.0)
#   点火延迟: 3.872e-05 s
# 计算进度: 394/425 (T=1475K, P=1.1atm, phi=1.1)
#   点火延迟: 3.474e-05 s
# 计算进度: 395/425 (T=1475K, P=1.1atm, phi=1.2)
#   点火延迟: 3.110e-05 s
# 计算进度: 396/425 (T=1475K, P=1.2atm, phi=0.8)
#   点火延迟: 3.562e-05 s
# 计算进度: 397/425 (T=1475K, P=1.2atm, phi=0.9)
#   点火延迟: 3.402e-05 s
# 计算进度: 398/425 (T=1475K, P=1.2atm, phi=1.0)
#   点火延迟: 3.338e-05 s
# 计算进度: 399/425 (T=1475K, P=1.2atm, phi=1.1)
#   点火延迟: 3.007e-05 s
# 计算进度: 400/425 (T=1475K, P=1.2atm, phi=1.2)
#   点火延迟: 2.792e-05 s
# 计算进度: 401/425 (T=1500K, P=0.8atm, phi=0.8)
#   点火延迟: 7.366e-05 s
# 计算进度: 402/425 (T=1500K, P=0.8atm, phi=0.9)
#   点火延迟: 7.176e-05 s
# 计算进度: 403/425 (T=1500K, P=0.8atm, phi=1.0)
#   点火延迟: 6.389e-05 s
# 计算进度: 404/425 (T=1500K, P=0.8atm, phi=1.1)
#   点火延迟: 5.591e-05 s
# 计算进度: 405/425 (T=1500K, P=0.8atm, phi=1.2)
#   点火延迟: 5.336e-05 s
# 计算进度: 406/425 (T=1500K, P=0.9atm, phi=0.8)
#   点火延迟: 6.403e-05 s
# 计算进度: 407/425 (T=1500K, P=0.9atm, phi=0.9)
#   点火延迟: 5.466e-05 s
# 计算进度: 408/425 (T=1500K, P=0.9atm, phi=1.0)
#   点火延迟: 5.253e-05 s
# 计算进度: 409/425 (T=1500K, P=0.9atm, phi=1.1)
#   点火延迟: 4.578e-05 s
# 计算进度: 410/425 (T=1500K, P=0.9atm, phi=1.2)
#   点火延迟: 4.499e-05 s
# 计算进度: 411/425 (T=1500K, P=1.0atm, phi=0.8)
#   点火延迟: 4.827e-05 s
# 计算进度: 412/425 (T=1500K, P=1.0atm, phi=0.9)
#   点火延迟: 4.806e-05 s
# 计算进度: 413/425 (T=1500K, P=1.0atm, phi=1.0)
#   点火延迟: 4.425e-05 s
# 计算进度: 414/425 (T=1500K, P=1.0atm, phi=1.1)
#   点火延迟: 4.001e-05 s
# 计算进度: 415/425 (T=1500K, P=1.0atm, phi=1.2)
#   点火延迟: 3.858e-05 s
# 计算进度: 416/425 (T=1500K, P=1.1atm, phi=0.8)
#   点火延迟: 4.157e-05 s
# 计算进度: 417/425 (T=1500K, P=1.1atm, phi=0.9)
#   点火延迟: 4.105e-05 s
# 计算进度: 418/425 (T=1500K, P=1.1atm, phi=1.0)
#   点火延迟: 3.720e-05 s
# 计算进度: 419/425 (T=1500K, P=1.1atm, phi=1.1)
#   点火延迟: 3.470e-05 s
# 计算进度: 420/425 (T=1500K, P=1.1atm, phi=1.2)
#   点火延迟: 3.118e-05 s
# 计算进度: 421/425 (T=1500K, P=1.2atm, phi=0.8)
#   点火延迟: 3.680e-05 s
# 计算进度: 422/425 (T=1500K, P=1.2atm, phi=0.9)
#   点火延迟: 3.405e-05 s
# 计算进度: 423/425 (T=1500K, P=1.2atm, phi=1.0)
#   点火延迟: 3.364e-05 s
# 计算进度: 424/425 (T=1500K, P=1.2atm, phi=1.1)
#   点火延迟: 2.841e-05 s
# 计算进度: 425/425 (T=1500K, P=1.2atm, phi=1.2)
#   点火延迟: 2.798e-05 s
#
# 总计算时间: 3.00 秒
#
# 结果已保存到 'ignition_delay_results.csv'
#
# 前5行数据预览:
#    Temperature_K  Pressure_atm  Equivalence_Ratio  Ignition_Delay_s
# 0            1.1           0.8                0.8          0.000143
# 1            1.1           0.8                0.9          0.000140
# 2            1.1           0.8                1.0          0.000138
# 3            1.1           0.8                1.1          0.000137
# 4            1.1           0.8                1.2          0.000135
#
# 成功计算: 425/425

# %%
# Dependencies: numpy, matplotlib, pandas
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import time
import cantera as ct

print('Running Cantera version: ' + ct.__version__)

def ignition_delay(states, species):
    """计算点火延迟时间"""
    i_ign = states(species).Y.argmax()
    return states.t[i_ign], states.T[i_ign]

def run_simulation(T, P, phi):
    """运行单个条件下的模拟"""
    # 创建气体对象并设置状态
    ideal_gas = ct.Solution('~/0/yaml/Burke2012_s9r23.yaml')
    ideal_gas.TP = T, P * 101325.0  # 转换为帕斯卡
    
    # 设置当量比
    ideal_gas.set_equivalence_ratio(phi=phi, fuel='H2',
                                    oxidizer={'O2': 2.0, 'N2': 3.76})
    
    # 创建反应器网络
    r = ct.Reactor(ideal_gas)
    reactor_network = ct.ReactorNet([r])
    time_history_IG = ct.SolutionArray(ideal_gas, extra=['t'])
    
    # 运行模拟
    t = 0
    counter = 1
    estimated_ignition_delay_time = 0.005
    
    while t < estimated_ignition_delay_time:
        t = reactor_network.step()
        if counter % 20 == 0:
            time_history_IG.append(r.thermo.state, t=t)
        counter += 1
    
    # 计算点火延迟
    tau_IG, _ = ignition_delay(time_history_IG, 'oh')
    
    return tau_IG

def main():
    """主函数：循环计算所有条件并保存结果"""
    # 定义参数范围
    T_range = np.arange(1100, 1525, 25)  # 1100-1500K，间隔25K
    P_range = np.arange(0.8, 1.21, 0.1)  # 0.8-1.2atm，间隔0.1atm
    phi_range = np.arange(0.8, 1.21, 0.1)  # 0.8-1.2，间隔0.1
    
    # 准备存储结果的列表
    results = []
    
    total_cases = len(T_range) * len(P_range) * len(phi_range)
    print(f"总计算条件数: {total_cases}")
    
    start_time = time.time()
    case_count = 0
    
    # 三重循环计算所有条件
    for T in T_range:
        for P in P_range:
            for phi in phi_range:
                case_count += 1
                
                print(f"计算进度: {case_count}/{total_cases} "
                      f"(T={T}K, P={P}atm, phi={phi})")
                
                try:
                    tau_IG = run_simulation(T, P, phi)
                    
                    # 保存结果
                    results.append({
                        'Temperature_K': T/1000,
                        'Pressure_atm': P,
                        'Equivalence_Ratio': phi,
                        'Ignition_Delay_s': tau_IG
                    })
                    
                    print(f"  点火延迟: {tau_IG:.3e} s")
                    
                except Exception as e:
                    print(f"  计算失败: {e}")
                    # 失败时保存NaN值
                    results.append({
                        'Temperature_K': T,
                        'Pressure_atm': P,
                        'Equivalence_Ratio': phi,
                        'Ignition_Delay_s': np.nan
                    })
    
    end_time = time.time()
    print(f"\n总计算时间: {end_time - start_time:.2f} 秒")
    
    # 转换为DataFrame并保存为CSV
    df_results = pd.DataFrame(results)
    df_results.to_csv('ignition_delay_results_pure.csv', index=False)
    print("\n结果已保存到 'ignition_delay_results_pure.csv'")
    
    # 显示前几行数据
    print("\n前5行数据预览:")
    print(df_results.head())
    
    # 统计成功计算的数量
    successful = df_results['Ignition_Delay_s'].notna().sum()
    print(f"\n成功计算: {successful}/{total_cases}")
    
    return df_results

if __name__ == "__main__":
    # 运行主程序
    data = main()
# Out:
# Running Cantera version: 3.1.0
# 总计算条件数: 425
# 计算进度: 1/425 (T=1100K, P=0.8atm, phi=0.8)
#   点火延迟: 9.841e-05 s
# 计算进度: 2/425 (T=1100K, P=0.8atm, phi=0.9)
#   点火延迟: 9.981e-05 s
# 计算进度: 3/425 (T=1100K, P=0.8atm, phi=1.0)
#   点火延迟: 9.777e-05 s
# 计算进度: 4/425 (T=1100K, P=0.8atm, phi=1.1)
#   点火延迟: 9.670e-05 s
# 计算进度: 5/425 (T=1100K, P=0.8atm, phi=1.2)
#   点火延迟: 9.629e-05 s
# 计算进度: 6/425 (T=1100K, P=0.9atm, phi=0.8)
#   点火延迟: 8.806e-05 s
# 计算进度: 7/425 (T=1100K, P=0.9atm, phi=0.9)
#   点火延迟: 8.742e-05 s
# 计算进度: 8/425 (T=1100K, P=0.9atm, phi=1.0)
#   点火延迟: 8.700e-05 s
# 计算进度: 9/425 (T=1100K, P=0.9atm, phi=1.1)
#   点火延迟: 8.505e-05 s
# 计算进度: 10/425 (T=1100K, P=0.9atm, phi=1.2)
#   点火延迟: 8.623e-05 s
# 计算进度: 11/425 (T=1100K, P=1.0atm, phi=0.8)
#   点火延迟: 7.865e-05 s
# 计算进度: 12/425 (T=1100K, P=1.0atm, phi=0.9)
#   点火延迟: 7.873e-05 s
# 计算进度: 13/425 (T=1100K, P=1.0atm, phi=1.0)
#   点火延迟: 7.824e-05 s
# 计算进度: 14/425 (T=1100K, P=1.0atm, phi=1.1)
#   点火延迟: 7.764e-05 s
# 计算进度: 15/425 (T=1100K, P=1.0atm, phi=1.2)
#   点火延迟: 7.718e-05 s
# 计算进度: 16/425 (T=1100K, P=1.1atm, phi=0.8)
#   点火延迟: 6.960e-05 s
# 计算进度: 17/425 (T=1100K, P=1.1atm, phi=0.9)
#   点火延迟: 7.084e-05 s
# 计算进度: 18/425 (T=1100K, P=1.1atm, phi=1.0)
#   点火延迟: 7.081e-05 s
# 计算进度: 19/425 (T=1100K, P=1.1atm, phi=1.1)
#   点火延迟: 6.964e-05 s
# 计算进度: 20/425 (T=1100K, P=1.1atm, phi=1.2)
#   点火延迟: 7.074e-05 s
# 计算进度: 21/425 (T=1100K, P=1.2atm, phi=0.8)
#   点火延迟: 6.424e-05 s
# 计算进度: 22/425 (T=1100K, P=1.2atm, phi=0.9)
#   点火延迟: 6.428e-05 s
# 计算进度: 23/425 (T=1100K, P=1.2atm, phi=1.0)
#   点火延迟: 6.494e-05 s
# 计算进度: 24/425 (T=1100K, P=1.2atm, phi=1.1)
#   点火延迟: 6.510e-05 s
# 计算进度: 25/425 (T=1100K, P=1.2atm, phi=1.2)
#   点火延迟: 6.533e-05 s
# 计算进度: 26/425 (T=1125K, P=0.8atm, phi=0.8)
#   点火延迟: 8.881e-05 s
# 计算进度: 27/425 (T=1125K, P=0.8atm, phi=0.9)
#   点火延迟: 9.049e-05 s
# 计算进度: 28/425 (T=1125K, P=0.8atm, phi=1.0)
#   点火延迟: 8.661e-05 s
# 计算进度: 29/425 (T=1125K, P=0.8atm, phi=1.1)
#   点火延迟: 8.522e-05 s
# 计算进度: 30/425 (T=1125K, P=0.8atm, phi=1.2)
#   点火延迟: 8.365e-05 s
# 计算进度: 31/425 (T=1125K, P=0.9atm, phi=0.8)
#   点火延迟: 7.670e-05 s
# 计算进度: 32/425 (T=1125K, P=0.9atm, phi=0.9)
#   点火延迟: 7.674e-05 s
# 计算进度: 33/425 (T=1125K, P=0.9atm, phi=1.0)
#   点火延迟: 7.533e-05 s
# 计算进度: 34/425 (T=1125K, P=0.9atm, phi=1.1)
#   点火延迟: 7.473e-05 s
# 计算进度: 35/425 (T=1125K, P=0.9atm, phi=1.2)
#   点火延迟: 7.442e-05 s
# 计算进度: 36/425 (T=1125K, P=1.0atm, phi=0.8)
#   点火延迟: 6.815e-05 s
# 计算进度: 37/425 (T=1125K, P=1.0atm, phi=0.9)
#   点火延迟: 6.779e-05 s
# 计算进度: 38/425 (T=1125K, P=1.0atm, phi=1.0)
#   点火延迟: 6.685e-05 s
# 计算进度: 39/425 (T=1125K, P=1.0atm, phi=1.1)
#   点火延迟: 6.716e-05 s
# 计算进度: 40/425 (T=1125K, P=1.0atm, phi=1.2)
#   点火延迟: 6.619e-05 s
# 计算进度: 41/425 (T=1125K, P=1.1atm, phi=0.8)
#   点火延迟: 6.102e-05 s
# 计算进度: 42/425 (T=1125K, P=1.1atm, phi=0.9)
#   点火延迟: 6.123e-05 s
# 计算进度: 43/425 (T=1125K, P=1.1atm, phi=1.0)
#   点火延迟: 6.031e-05 s
# 计算进度: 44/425 (T=1125K, P=1.1atm, phi=1.1)
#   点火延迟: 5.978e-05 s
# 计算进度: 45/425 (T=1125K, P=1.1atm, phi=1.2)
#   点火延迟: 5.968e-05 s
# 计算进度: 46/425 (T=1125K, P=1.2atm, phi=0.8)
#   点火延迟: 5.632e-05 s
# 计算进度: 47/425 (T=1125K, P=1.2atm, phi=0.9)
#   点火延迟: 5.515e-05 s
# 计算进度: 48/425 (T=1125K, P=1.2atm, phi=1.0)
#   点火延迟: 5.534e-05 s
# 计算进度: 49/425 (T=1125K, P=1.2atm, phi=1.1)
#   点火延迟: 5.465e-05 s
# 计算进度: 50/425 (T=1125K, P=1.2atm, phi=1.2)
#   点火延迟: 5.490e-05 s
# 计算进度: 51/425 (T=1150K, P=0.8atm, phi=0.8)
#   点火延迟: 8.049e-05 s
# 计算进度: 52/425 (T=1150K, P=0.8atm, phi=0.9)
#   点火延迟: 8.061e-05 s
# 计算进度: 53/425 (T=1150K, P=0.8atm, phi=1.0)
#   点火延迟: 7.673e-05 s
# 计算进度: 54/425 (T=1150K, P=0.8atm, phi=1.1)
#   点火延迟: 7.598e-05 s
# 计算进度: 55/425 (T=1150K, P=0.8atm, phi=1.2)
#   点火延迟: 7.440e-05 s
# 计算进度: 56/425 (T=1150K, P=0.9atm, phi=0.8)
#   点火延迟: 6.854e-05 s
# 计算进度: 57/425 (T=1150K, P=0.9atm, phi=0.9)
#   点火延迟: 6.924e-05 s
# 计算进度: 58/425 (T=1150K, P=0.9atm, phi=1.0)
#   点火延迟: 6.684e-05 s
# 计算进度: 59/425 (T=1150K, P=0.9atm, phi=1.1)
#   点火延迟: 6.669e-05 s
# 计算进度: 60/425 (T=1150K, P=0.9atm, phi=1.2)
#   点火延迟: 6.519e-05 s
# 计算进度: 61/425 (T=1150K, P=1.0atm, phi=0.8)
#   点火延迟: 6.162e-05 s
# 计算进度: 62/425 (T=1150K, P=1.0atm, phi=0.9)
#   点火延迟: 6.005e-05 s
# 计算进度: 63/425 (T=1150K, P=1.0atm, phi=1.0)
#   点火延迟: 5.922e-05 s
# 计算进度: 64/425 (T=1150K, P=1.0atm, phi=1.1)
#   点火延迟: 5.913e-05 s
# 计算进度: 65/425 (T=1150K, P=1.0atm, phi=1.2)
#   点火延迟: 5.717e-05 s
# 计算进度: 66/425 (T=1150K, P=1.1atm, phi=0.8)
#   点火延迟: 5.461e-05 s
# 计算进度: 67/425 (T=1150K, P=1.1atm, phi=0.9)
#   点火延迟: 5.409e-05 s
# 计算进度: 68/425 (T=1150K, P=1.1atm, phi=1.0)
#   点火延迟: 5.282e-05 s
# 计算进度: 69/425 (T=1150K, P=1.1atm, phi=1.1)
#   点火延迟: 5.297e-05 s
# 计算进度: 70/425 (T=1150K, P=1.1atm, phi=1.2)
#   点火延迟: 5.189e-05 s
# 计算进度: 71/425 (T=1150K, P=1.2atm, phi=0.8)
#   点火延迟: 4.953e-05 s
# 计算进度: 72/425 (T=1150K, P=1.2atm, phi=0.9)
#   点火延迟: 4.857e-05 s
# 计算进度: 73/425 (T=1150K, P=1.2atm, phi=1.0)
#   点火延迟: 4.784e-05 s
# 计算进度: 74/425 (T=1150K, P=1.2atm, phi=1.1)
#   点火延迟: 4.842e-05 s
# 计算进度: 75/425 (T=1150K, P=1.2atm, phi=1.2)
#   点火延迟: 4.770e-05 s
# 计算进度: 76/425 (T=1175K, P=0.8atm, phi=0.8)
#   点火延迟: 7.546e-05 s
# 计算进度: 77/425 (T=1175K, P=0.8atm, phi=0.9)
#   点火延迟: 7.266e-05 s
# 计算进度: 78/425 (T=1175K, P=0.8atm, phi=1.0)
#   点火延迟: 7.103e-05 s
# 计算进度: 79/425 (T=1175K, P=0.8atm, phi=1.1)
#   点火延迟: 6.876e-05 s
# 计算进度: 80/425 (T=1175K, P=0.8atm, phi=1.2)
#   点火延迟: 6.762e-05 s
# 计算进度: 81/425 (T=1175K, P=0.9atm, phi=0.8)
#   点火延迟: 6.386e-05 s
# 计算进度: 82/425 (T=1175K, P=0.9atm, phi=0.9)
#   点火延迟: 6.373e-05 s
# 计算进度: 83/425 (T=1175K, P=0.9atm, phi=1.0)
#   点火延迟: 6.262e-05 s
# 计算进度: 84/425 (T=1175K, P=0.9atm, phi=1.1)
#   点火延迟: 5.970e-05 s
# 计算进度: 85/425 (T=1175K, P=0.9atm, phi=1.2)
#   点火延迟: 5.761e-05 s
# 计算进度: 86/425 (T=1175K, P=1.0atm, phi=0.8)
#   点火延迟: 5.523e-05 s
# 计算进度: 87/425 (T=1175K, P=1.0atm, phi=0.9)
#   点火延迟: 5.536e-05 s
# 计算进度: 88/425 (T=1175K, P=1.0atm, phi=1.0)
#   点火延迟: 5.463e-05 s
# 计算进度: 89/425 (T=1175K, P=1.0atm, phi=1.1)
#   点火延迟: 5.214e-05 s
# 计算进度: 90/425 (T=1175K, P=1.0atm, phi=1.2)
#   点火延迟: 5.206e-05 s
# 计算进度: 91/425 (T=1175K, P=1.1atm, phi=0.8)
#   点火延迟: 4.815e-05 s
# 计算进度: 92/425 (T=1175K, P=1.1atm, phi=0.9)
#   点火延迟: 4.907e-05 s
# 计算进度: 93/425 (T=1175K, P=1.1atm, phi=1.0)
#   点火延迟: 4.775e-05 s
# 计算进度: 94/425 (T=1175K, P=1.1atm, phi=1.1)
#   点火延迟: 4.654e-05 s
# 计算进度: 95/425 (T=1175K, P=1.1atm, phi=1.2)
#   点火延迟: 4.588e-05 s
# 计算进度: 96/425 (T=1175K, P=1.2atm, phi=0.8)
#   点火延迟: 4.378e-05 s
# 计算进度: 97/425 (T=1175K, P=1.2atm, phi=0.9)
#   点火延迟: 4.331e-05 s
# 计算进度: 98/425 (T=1175K, P=1.2atm, phi=1.0)
#   点火延迟: 4.320e-05 s
# 计算进度: 99/425 (T=1175K, P=1.2atm, phi=1.1)
#   点火延迟: 4.261e-05 s
# 计算进度: 100/425 (T=1175K, P=1.2atm, phi=1.2)
#   点火延迟: 4.180e-05 s
# 计算进度: 101/425 (T=1200K, P=0.8atm, phi=0.8)
#   点火延迟: 6.997e-05 s
# 计算进度: 102/425 (T=1200K, P=0.8atm, phi=0.9)
#   点火延迟: 7.041e-05 s
# 计算进度: 103/425 (T=1200K, P=0.8atm, phi=1.0)
#   点火延迟: 6.474e-05 s
# 计算进度: 104/425 (T=1200K, P=0.8atm, phi=1.1)
#   点火延迟: 6.257e-05 s
# 计算进度: 105/425 (T=1200K, P=0.8atm, phi=1.2)
#   点火延迟: 6.150e-05 s
# 计算进度: 106/425 (T=1200K, P=0.9atm, phi=0.8)
#   点火延迟: 5.867e-05 s
# 计算进度: 107/425 (T=1200K, P=0.9atm, phi=0.9)
#   点火延迟: 5.666e-05 s
# 计算进度: 108/425 (T=1200K, P=0.9atm, phi=1.0)
#   点火延迟: 5.575e-05 s
# 计算进度: 109/425 (T=1200K, P=0.9atm, phi=1.1)
#   点火延迟: 5.425e-05 s
# 计算进度: 110/425 (T=1200K, P=0.9atm, phi=1.2)
#   点火延迟: 5.301e-05 s
# 计算进度: 111/425 (T=1200K, P=1.0atm, phi=0.8)
#   点火延迟: 5.222e-05 s
# 计算进度: 112/425 (T=1200K, P=1.0atm, phi=0.9)
#   点火延迟: 5.113e-05 s
# 计算进度: 113/425 (T=1200K, P=1.0atm, phi=1.0)
#   点火延迟: 4.923e-05 s
# 计算进度: 114/425 (T=1200K, P=1.0atm, phi=1.1)
#   点火延迟: 4.693e-05 s
# 计算进度: 115/425 (T=1200K, P=1.0atm, phi=1.2)
#   点火延迟: 4.667e-05 s
# 计算进度: 116/425 (T=1200K, P=1.1atm, phi=0.8)
#   点火延迟: 4.471e-05 s
# 计算进度: 117/425 (T=1200K, P=1.1atm, phi=0.9)
#   点火延迟: 4.559e-05 s
# 计算进度: 118/425 (T=1200K, P=1.1atm, phi=1.0)
#   点火延迟: 4.342e-05 s
# 计算进度: 119/425 (T=1200K, P=1.1atm, phi=1.1)
#   点火延迟: 4.252e-05 s
# 计算进度: 120/425 (T=1200K, P=1.1atm, phi=1.2)
#   点火延迟: 4.135e-05 s
# 计算进度: 121/425 (T=1200K, P=1.2atm, phi=0.8)
#   点火延迟: 3.979e-05 s
# 计算进度: 122/425 (T=1200K, P=1.2atm, phi=0.9)
#   点火延迟: 3.953e-05 s
# 计算进度: 123/425 (T=1200K, P=1.2atm, phi=1.0)
#   点火延迟: 3.957e-05 s
# 计算进度: 124/425 (T=1200K, P=1.2atm, phi=1.1)
#   点火延迟: 3.805e-05 s
# 计算进度: 125/425 (T=1200K, P=1.2atm, phi=1.2)
#   点火延迟: 3.734e-05 s
# 计算进度: 126/425 (T=1225K, P=0.8atm, phi=0.8)
#   点火延迟: 6.519e-05 s
# 计算进度: 127/425 (T=1225K, P=0.8atm, phi=0.9)
#   点火延迟: 6.603e-05 s
# 计算进度: 128/425 (T=1225K, P=0.8atm, phi=1.0)
#   点火延迟: 6.238e-05 s
# 计算进度: 129/425 (T=1225K, P=0.8atm, phi=1.1)
#   点火延迟: 5.745e-05 s
# 计算进度: 130/425 (T=1225K, P=0.8atm, phi=1.2)
#   点火延迟: 5.680e-05 s
# 计算进度: 131/425 (T=1225K, P=0.9atm, phi=0.8)
#   点火延迟: 5.502e-05 s
# 计算进度: 132/425 (T=1225K, P=0.9atm, phi=0.9)
#   点火延迟: 5.340e-05 s
# 计算进度: 133/425 (T=1225K, P=0.9atm, phi=1.0)
#   点火延迟: 5.293e-05 s
# 计算进度: 134/425 (T=1225K, P=0.9atm, phi=1.1)
#   点火延迟: 4.992e-05 s
# 计算进度: 135/425 (T=1225K, P=0.9atm, phi=1.2)
#   点火延迟: 4.762e-05 s
# 计算进度: 136/425 (T=1225K, P=1.0atm, phi=0.8)
#   点火延迟: 4.855e-05 s
# 计算进度: 137/425 (T=1225K, P=1.0atm, phi=0.9)
#   点火延迟: 4.663e-05 s
# 计算进度: 138/425 (T=1225K, P=1.0atm, phi=1.0)
#   点火延迟: 4.465e-05 s
# 计算进度: 139/425 (T=1225K, P=1.0atm, phi=1.1)
#   点火延迟: 4.450e-05 s
# 计算进度: 140/425 (T=1225K, P=1.0atm, phi=1.2)
#   点火延迟: 4.197e-05 s
# 计算进度: 141/425 (T=1225K, P=1.1atm, phi=0.8)
#   点火延迟: 4.225e-05 s
# 计算进度: 142/425 (T=1225K, P=1.1atm, phi=0.9)
#   点火延迟: 4.182e-05 s
# 计算进度: 143/425 (T=1225K, P=1.1atm, phi=1.0)
#   点火延迟: 4.017e-05 s
# 计算进度: 144/425 (T=1225K, P=1.1atm, phi=1.1)
#   点火延迟: 3.802e-05 s
# 计算进度: 145/425 (T=1225K, P=1.1atm, phi=1.2)
#   点火延迟: 3.712e-05 s
# 计算进度: 146/425 (T=1225K, P=1.2atm, phi=0.8)
#   点火延迟: 3.730e-05 s
# 计算进度: 147/425 (T=1225K, P=1.2atm, phi=0.9)
#   点火延迟: 3.653e-05 s
# 计算进度: 148/425 (T=1225K, P=1.2atm, phi=1.0)
#   点火延迟: 3.586e-05 s
# 计算进度: 149/425 (T=1225K, P=1.2atm, phi=1.1)
#   点火延迟: 3.411e-05 s
# 计算进度: 150/425 (T=1225K, P=1.2atm, phi=1.2)
#   点火延迟: 3.401e-05 s
# 计算进度: 151/425 (T=1250K, P=0.8atm, phi=0.8)
#   点火延迟: 6.308e-05 s
# 计算进度: 152/425 (T=1250K, P=0.8atm, phi=0.9)
#   点火延迟: 6.173e-05 s
# 计算进度: 153/425 (T=1250K, P=0.8atm, phi=1.0)
#   点火延迟: 5.725e-05 s
# 计算进度: 154/425 (T=1250K, P=0.8atm, phi=1.1)
#   点火延迟: 5.573e-05 s
# 计算进度: 155/425 (T=1250K, P=0.8atm, phi=1.2)
#   点火延迟: 5.128e-05 s
# 计算进度: 156/425 (T=1250K, P=0.9atm, phi=0.8)
#   点火延迟: 5.240e-05 s
# 计算进度: 157/425 (T=1250K, P=0.9atm, phi=0.9)
#   点火延迟: 5.109e-05 s
# 计算进度: 158/425 (T=1250K, P=0.9atm, phi=1.0)
#   点火延迟: 4.918e-05 s
# 计算进度: 159/425 (T=1250K, P=0.9atm, phi=1.1)
#   点火延迟: 4.723e-05 s
# 计算进度: 160/425 (T=1250K, P=0.9atm, phi=1.2)
#   点火延迟: 4.568e-05 s
# 计算进度: 161/425 (T=1250K, P=1.0atm, phi=0.8)
#   点火延迟: 4.605e-05 s
# 计算进度: 162/425 (T=1250K, P=1.0atm, phi=0.9)
#   点火延迟: 4.371e-05 s
# 计算进度: 163/425 (T=1250K, P=1.0atm, phi=1.0)
#   点火延迟: 4.277e-05 s
# 计算进度: 164/425 (T=1250K, P=1.0atm, phi=1.1)
#   点火延迟: 3.969e-05 s
# 计算进度: 165/425 (T=1250K, P=1.0atm, phi=1.2)
#   点火延迟: 3.855e-05 s
# 计算进度: 166/425 (T=1250K, P=1.1atm, phi=0.8)
#   点火延迟: 3.865e-05 s
# 计算进度: 167/425 (T=1250K, P=1.1atm, phi=0.9)
#   点火延迟: 3.932e-05 s
# 计算进度: 168/425 (T=1250K, P=1.1atm, phi=1.0)
#   点火延迟: 3.722e-05 s
# 计算进度: 169/425 (T=1250K, P=1.1atm, phi=1.1)
#   点火延迟: 3.519e-05 s
# 计算进度: 170/425 (T=1250K, P=1.1atm, phi=1.2)
#   点火延迟: 3.444e-05 s
# 计算进度: 171/425 (T=1250K, P=1.2atm, phi=0.8)
#   点火延迟: 3.438e-05 s
# 计算进度: 172/425 (T=1250K, P=1.2atm, phi=0.9)
#   点火延迟: 3.358e-05 s
# 计算进度: 173/425 (T=1250K, P=1.2atm, phi=1.0)
#   点火延迟: 3.343e-05 s
# 计算进度: 174/425 (T=1250K, P=1.2atm, phi=1.1)
#   点火延迟: 3.173e-05 s
# 计算进度: 175/425 (T=1250K, P=1.2atm, phi=1.2)
#   点火延迟: 3.098e-05 s
# 计算进度: 176/425 (T=1275K, P=0.8atm, phi=0.8)
#   点火延迟: 5.993e-05 s
# 计算进度: 177/425 (T=1275K, P=0.8atm, phi=0.9)
#   点火延迟: 6.259e-05 s
# 计算进度: 178/425 (T=1275K, P=0.8atm, phi=1.0)
#   点火延迟: 5.702e-05 s
# 计算进度: 179/425 (T=1275K, P=0.8atm, phi=1.1)
#   点火延迟: 5.391e-05 s
# 计算进度: 180/425 (T=1275K, P=0.8atm, phi=1.2)
#   点火延迟: 4.946e-05 s
# 计算进度: 181/425 (T=1275K, P=0.9atm, phi=0.8)
#   点火延迟: 5.008e-05 s
# 计算进度: 182/425 (T=1275K, P=0.9atm, phi=0.9)
#   点火延迟: 4.934e-05 s
# 计算进度: 183/425 (T=1275K, P=0.9atm, phi=1.0)
#   点火延迟: 4.739e-05 s
# 计算进度: 184/425 (T=1275K, P=0.9atm, phi=1.1)
#   点火延迟: 4.415e-05 s
# 计算进度: 185/425 (T=1275K, P=0.9atm, phi=1.2)
#   点火延迟: 4.283e-05 s
# 计算进度: 186/425 (T=1275K, P=1.0atm, phi=0.8)
#   点火延迟: 4.211e-05 s
# 计算进度: 187/425 (T=1275K, P=1.0atm, phi=0.9)
#   点火延迟: 4.344e-05 s
# 计算进度: 188/425 (T=1275K, P=1.0atm, phi=1.0)
#   点火延迟: 3.969e-05 s
# 计算进度: 189/425 (T=1275K, P=1.0atm, phi=1.1)
#   点火延迟: 3.774e-05 s
# 计算进度: 190/425 (T=1275K, P=1.0atm, phi=1.2)
#   点火延迟: 3.707e-05 s
# 计算进度: 191/425 (T=1275K, P=1.1atm, phi=0.8)
#   点火延迟: 3.761e-05 s
# 计算进度: 192/425 (T=1275K, P=1.1atm, phi=0.9)
#   点火延迟: 3.779e-05 s
# 计算进度: 193/425 (T=1275K, P=1.1atm, phi=1.0)
#   点火延迟: 3.512e-05 s
# 计算进度: 194/425 (T=1275K, P=1.1atm, phi=1.1)
#   点火延迟: 3.229e-05 s
# 计算进度: 195/425 (T=1275K, P=1.1atm, phi=1.2)
#   点火延迟: 3.225e-05 s
# 计算进度: 196/425 (T=1275K, P=1.2atm, phi=0.8)
#   点火延迟: 3.211e-05 s
# 计算进度: 197/425 (T=1275K, P=1.2atm, phi=0.9)
#   点火延迟: 3.267e-05 s
# 计算进度: 198/425 (T=1275K, P=1.2atm, phi=1.0)
#   点火延迟: 3.130e-05 s
# 计算进度: 199/425 (T=1275K, P=1.2atm, phi=1.1)
#   点火延迟: 2.965e-05 s
# 计算进度: 200/425 (T=1275K, P=1.2atm, phi=1.2)
#   点火延迟: 2.844e-05 s
# 计算进度: 201/425 (T=1300K, P=0.8atm, phi=0.8)
#   点火延迟: 5.944e-05 s
# 计算进度: 202/425 (T=1300K, P=0.8atm, phi=0.9)
#   点火延迟: 5.813e-05 s
# 计算进度: 203/425 (T=1300K, P=0.8atm, phi=1.0)
#   点火延迟: 5.473e-05 s
# 计算进度: 204/425 (T=1300K, P=0.8atm, phi=1.1)
#   点火延迟: 5.021e-05 s
# 计算进度: 205/425 (T=1300K, P=0.8atm, phi=1.2)
#   点火延迟: 4.776e-05 s
# 计算进度: 206/425 (T=1300K, P=0.9atm, phi=0.8)
#   点火延迟: 5.023e-05 s
# 计算进度: 207/425 (T=1300K, P=0.9atm, phi=0.9)
#   点火延迟: 4.897e-05 s
# 计算进度: 208/425 (T=1300K, P=0.9atm, phi=1.0)
#   点火延迟: 4.545e-05 s
# 计算进度: 209/425 (T=1300K, P=0.9atm, phi=1.1)
#   点火延迟: 4.276e-05 s
# 计算进度: 210/425 (T=1300K, P=0.9atm, phi=1.2)
#   点火延迟: 3.890e-05 s
# 计算进度: 211/425 (T=1300K, P=1.0atm, phi=0.8)
#   点火延迟: 4.160e-05 s
# 计算进度: 212/425 (T=1300K, P=1.0atm, phi=0.9)
#   点火延迟: 4.082e-05 s
# 计算进度: 213/425 (T=1300K, P=1.0atm, phi=1.0)
#   点火延迟: 3.807e-05 s
# 计算进度: 214/425 (T=1300K, P=1.0atm, phi=1.1)
#   点火延迟: 3.535e-05 s
# 计算进度: 215/425 (T=1300K, P=1.0atm, phi=1.2)
#   点火延迟: 3.368e-05 s
# 计算进度: 216/425 (T=1300K, P=1.1atm, phi=0.8)
#   点火延迟: 3.523e-05 s
# 计算进度: 217/425 (T=1300K, P=1.1atm, phi=0.9)
#   点火延迟: 3.564e-05 s
# 计算进度: 218/425 (T=1300K, P=1.1atm, phi=1.0)
#   点火延迟: 3.434e-05 s
# 计算进度: 219/425 (T=1300K, P=1.1atm, phi=1.1)
#   点火延迟: 3.091e-05 s
# 计算进度: 220/425 (T=1300K, P=1.1atm, phi=1.2)
#   点火延迟: 2.964e-05 s
# 计算进度: 221/425 (T=1300K, P=1.2atm, phi=0.8)
#   点火延迟: 3.029e-05 s
# 计算进度: 222/425 (T=1300K, P=1.2atm, phi=0.9)
#   点火延迟: 3.080e-05 s
# 计算进度: 223/425 (T=1300K, P=1.2atm, phi=1.0)
#   点火延迟: 2.975e-05 s
# 计算进度: 224/425 (T=1300K, P=1.2atm, phi=1.1)
#   点火延迟: 2.778e-05 s
# 计算进度: 225/425 (T=1300K, P=1.2atm, phi=1.2)
#   点火延迟: 2.639e-05 s
# 计算进度: 226/425 (T=1325K, P=0.8atm, phi=0.8)
#   点火延迟: 5.823e-05 s
# 计算进度: 227/425 (T=1325K, P=0.8atm, phi=0.9)
#   点火延迟: 6.217e-05 s
# 计算进度: 228/425 (T=1325K, P=0.8atm, phi=1.0)
#   点火延迟: 5.371e-05 s
# 计算进度: 229/425 (T=1325K, P=0.8atm, phi=1.1)
#   点火延迟: 4.804e-05 s
# 计算进度: 230/425 (T=1325K, P=0.8atm, phi=1.2)
#   点火延迟: 4.650e-05 s
# 计算进度: 231/425 (T=1325K, P=0.9atm, phi=0.8)
#   点火延迟: 4.958e-05 s
# 计算进度: 232/425 (T=1325K, P=0.9atm, phi=0.9)
#   点火延迟: 4.864e-05 s
# 计算进度: 233/425 (T=1325K, P=0.9atm, phi=1.0)
#   点火延迟: 4.300e-05 s
# 计算进度: 234/425 (T=1325K, P=0.9atm, phi=1.1)
#   点火延迟: 3.970e-05 s
# 计算进度: 235/425 (T=1325K, P=0.9atm, phi=1.2)
#   点火延迟: 3.769e-05 s
# 计算进度: 236/425 (T=1325K, P=1.0atm, phi=0.8)
#   点火延迟: 4.136e-05 s
# 计算进度: 237/425 (T=1325K, P=1.0atm, phi=0.9)
#   点火延迟: 4.186e-05 s
# 计算进度: 238/425 (T=1325K, P=1.0atm, phi=1.0)
#   点火延迟: 3.789e-05 s
# 计算进度: 239/425 (T=1325K, P=1.0atm, phi=1.1)
#   点火延迟: 3.382e-05 s
# 计算进度: 240/425 (T=1325K, P=1.0atm, phi=1.2)
#   点火延迟: 3.335e-05 s
# 计算进度: 241/425 (T=1325K, P=1.1atm, phi=0.8)
#   点火延迟: 3.577e-05 s
# 计算进度: 242/425 (T=1325K, P=1.1atm, phi=0.9)
#   点火延迟: 3.535e-05 s
# 计算进度: 243/425 (T=1325K, P=1.1atm, phi=1.0)
#   点火延迟: 3.181e-05 s
# 计算进度: 244/425 (T=1325K, P=1.1atm, phi=1.1)
#   点火延迟: 2.991e-05 s
# 计算进度: 245/425 (T=1325K, P=1.1atm, phi=1.2)
#   点火延迟: 2.890e-05 s
# 计算进度: 246/425 (T=1325K, P=1.2atm, phi=0.8)
#   点火延迟: 3.009e-05 s
# 计算进度: 247/425 (T=1325K, P=1.2atm, phi=0.9)
#   点火延迟: 3.085e-05 s
# 计算进度: 248/425 (T=1325K, P=1.2atm, phi=1.0)
#   点火延迟: 2.809e-05 s
# 计算进度: 249/425 (T=1325K, P=1.2atm, phi=1.1)
#   点火延迟: 2.660e-05 s
# 计算进度: 250/425 (T=1325K, P=1.2atm, phi=1.2)
#   点火延迟: 2.510e-05 s
# 计算进度: 251/425 (T=1350K, P=0.8atm, phi=0.8)
#   点火延迟: 6.212e-05 s
# 计算进度: 252/425 (T=1350K, P=0.8atm, phi=0.9)
#   点火延迟: 6.825e-05 s
# 计算进度: 253/425 (T=1350K, P=0.8atm, phi=1.0)
#   点火延迟: 5.569e-05 s
# 计算进度: 254/425 (T=1350K, P=0.8atm, phi=1.1)
#   点火延迟: 4.639e-05 s
# 计算进度: 255/425 (T=1350K, P=0.8atm, phi=1.2)
#   点火延迟: 4.415e-05 s
# 计算进度: 256/425 (T=1350K, P=0.9atm, phi=0.8)
#   点火延迟: 4.986e-05 s
# 计算进度: 257/425 (T=1350K, P=0.9atm, phi=0.9)
#   点火延迟: 4.720e-05 s
# 计算进度: 258/425 (T=1350K, P=0.9atm, phi=1.0)
#   点火延迟: 4.368e-05 s
# 计算进度: 259/425 (T=1350K, P=0.9atm, phi=1.1)
#   点火延迟: 3.864e-05 s
# 计算进度: 260/425 (T=1350K, P=0.9atm, phi=1.2)
#   点火延迟: 3.581e-05 s
# 计算进度: 261/425 (T=1350K, P=1.0atm, phi=0.8)
#   点火延迟: 3.868e-05 s
# 计算进度: 262/425 (T=1350K, P=1.0atm, phi=0.9)
#   点火延迟: 3.881e-05 s
# 计算进度: 263/425 (T=1350K, P=1.0atm, phi=1.0)
#   点火延迟: 3.596e-05 s
# 计算进度: 264/425 (T=1350K, P=1.0atm, phi=1.1)
#   点火延迟: 3.432e-05 s
# 计算进度: 265/425 (T=1350K, P=1.0atm, phi=1.2)
#   点火延迟: 3.127e-05 s
# 计算进度: 266/425 (T=1350K, P=1.1atm, phi=0.8)
#   点火延迟: 3.439e-05 s
# 计算进度: 267/425 (T=1350K, P=1.1atm, phi=0.9)
#   点火延迟: 3.290e-05 s
# 计算进度: 268/425 (T=1350K, P=1.1atm, phi=1.0)
#   点火延迟: 3.166e-05 s
# 计算进度: 269/425 (T=1350K, P=1.1atm, phi=1.1)
#   点火延迟: 2.825e-05 s
# 计算进度: 270/425 (T=1350K, P=1.1atm, phi=1.2)
#   点火延迟: 2.717e-05 s
# 计算进度: 271/425 (T=1350K, P=1.2atm, phi=0.8)
#   点火延迟: 2.935e-05 s
# 计算进度: 272/425 (T=1350K, P=1.2atm, phi=0.9)
#   点火延迟: 2.992e-05 s
# 计算进度: 273/425 (T=1350K, P=1.2atm, phi=1.0)
#   点火延迟: 2.636e-05 s
# 计算进度: 274/425 (T=1350K, P=1.2atm, phi=1.1)
#   点火延迟: 2.472e-05 s
# 计算进度: 275/425 (T=1350K, P=1.2atm, phi=1.2)
#   点火延迟: 2.457e-05 s
# 计算进度: 276/425 (T=1375K, P=0.8atm, phi=0.8)
#   点火延迟: 6.556e-05 s
# 计算进度: 277/425 (T=1375K, P=0.8atm, phi=0.9)
#   点火延迟: 6.925e-05 s
# 计算进度: 278/425 (T=1375K, P=0.8atm, phi=1.0)
#   点火延迟: 5.747e-05 s
# 计算进度: 279/425 (T=1375K, P=0.8atm, phi=1.1)
#   点火延迟: 4.564e-05 s
# 计算进度: 280/425 (T=1375K, P=0.8atm, phi=1.2)
#   点火延迟: 4.156e-05 s
# 计算进度: 281/425 (T=1375K, P=0.9atm, phi=0.8)
#   点火延迟: 4.957e-05 s
# 计算进度: 282/425 (T=1375K, P=0.9atm, phi=0.9)
#   点火延迟: 4.971e-05 s
# 计算进度: 283/425 (T=1375K, P=0.9atm, phi=1.0)
#   点火延迟: 4.202e-05 s
# 计算进度: 284/425 (T=1375K, P=0.9atm, phi=1.1)
#   点火延迟: 3.857e-05 s
# 计算进度: 285/425 (T=1375K, P=0.9atm, phi=1.2)
#   点火延迟: 3.485e-05 s
# 计算进度: 286/425 (T=1375K, P=1.0atm, phi=0.8)
#   点火延迟: 3.869e-05 s
# 计算进度: 287/425 (T=1375K, P=1.0atm, phi=0.9)
#   点火延迟: 3.953e-05 s
# 计算进度: 288/425 (T=1375K, P=1.0atm, phi=1.0)
#   点火延迟: 3.487e-05 s
# 计算进度: 289/425 (T=1375K, P=1.0atm, phi=1.1)
#   点火延迟: 3.184e-05 s
# 计算进度: 290/425 (T=1375K, P=1.0atm, phi=1.2)
#   点火延迟: 2.931e-05 s
# 计算进度: 291/425 (T=1375K, P=1.1atm, phi=0.8)
#   点火延迟: 3.444e-05 s
# 计算进度: 292/425 (T=1375K, P=1.1atm, phi=0.9)
#   点火延迟: 3.331e-05 s
# 计算进度: 293/425 (T=1375K, P=1.1atm, phi=1.0)
#   点火延迟: 3.023e-05 s
# 计算进度: 294/425 (T=1375K, P=1.1atm, phi=1.1)
#   点火延迟: 2.679e-05 s
# 计算进度: 295/425 (T=1375K, P=1.1atm, phi=1.2)
#   点火延迟: 2.684e-05 s
# 计算进度: 296/425 (T=1375K, P=1.2atm, phi=0.8)
#   点火延迟: 2.811e-05 s
# 计算进度: 297/425 (T=1375K, P=1.2atm, phi=0.9)
#   点火延迟: 2.944e-05 s
# 计算进度: 298/425 (T=1375K, P=1.2atm, phi=1.0)
#   点火延迟: 2.641e-05 s
# 计算进度: 299/425 (T=1375K, P=1.2atm, phi=1.1)
#   点火延迟: 2.442e-05 s
# 计算进度: 300/425 (T=1375K, P=1.2atm, phi=1.2)
#   点火延迟: 2.328e-05 s
# 计算进度: 301/425 (T=1400K, P=0.8atm, phi=0.8)
#   点火延迟: 7.403e-05 s
# 计算进度: 302/425 (T=1400K, P=0.8atm, phi=0.9)
#   点火延迟: 1.909e-04 s
# 计算进度: 303/425 (T=1400K, P=0.8atm, phi=1.0)
#   点火延迟: 5.874e-05 s
# 计算进度: 304/425 (T=1400K, P=0.8atm, phi=1.1)
#   点火延迟: 4.800e-05 s
# 计算进度: 305/425 (T=1400K, P=0.8atm, phi=1.2)
#   点火延迟: 4.105e-05 s
# 计算进度: 306/425 (T=1400K, P=0.9atm, phi=0.8)
#   点火延迟: 5.278e-05 s
# 计算进度: 307/425 (T=1400K, P=0.9atm, phi=0.9)
#   点火延迟: 5.129e-05 s
# 计算进度: 308/425 (T=1400K, P=0.9atm, phi=1.0)
#   点火延迟: 4.494e-05 s
# 计算进度: 309/425 (T=1400K, P=0.9atm, phi=1.1)
#   点火延迟: 3.717e-05 s
# 计算进度: 310/425 (T=1400K, P=0.9atm, phi=1.2)
#   点火延迟: 3.376e-05 s
# 计算进度: 311/425 (T=1400K, P=1.0atm, phi=0.8)
#   点火延迟: 4.030e-05 s
# 计算进度: 312/425 (T=1400K, P=1.0atm, phi=0.9)
#   点火延迟: 3.951e-05 s
# 计算进度: 313/425 (T=1400K, P=1.0atm, phi=1.0)
#   点火延迟: 3.593e-05 s
# 计算进度: 314/425 (T=1400K, P=1.0atm, phi=1.1)
#   点火延迟: 3.186e-05 s
# 计算进度: 315/425 (T=1400K, P=1.0atm, phi=1.2)
#   点火延迟: 2.989e-05 s
# 计算进度: 316/425 (T=1400K, P=1.1atm, phi=0.8)
#   点火延迟: 3.329e-05 s
# 计算进度: 317/425 (T=1400K, P=1.1atm, phi=0.9)
#   点火延迟: 3.297e-05 s
# 计算进度: 318/425 (T=1400K, P=1.1atm, phi=1.0)
#   点火延迟: 2.936e-05 s
# 计算进度: 319/425 (T=1400K, P=1.1atm, phi=1.1)
#   点火延迟: 2.683e-05 s
# 计算进度: 320/425 (T=1400K, P=1.1atm, phi=1.2)
#   点火延迟: 2.538e-05 s
# 计算进度: 321/425 (T=1400K, P=1.2atm, phi=0.8)
#   点火延迟: 2.877e-05 s
# 计算进度: 322/425 (T=1400K, P=1.2atm, phi=0.9)
#   点火延迟: 2.903e-05 s
# 计算进度: 323/425 (T=1400K, P=1.2atm, phi=1.0)
#   点火延迟: 2.631e-05 s
# 计算进度: 324/425 (T=1400K, P=1.2atm, phi=1.1)
#   点火延迟: 2.347e-05 s
# 计算进度: 325/425 (T=1400K, P=1.2atm, phi=1.2)
#   点火延迟: 2.253e-05 s
# 计算进度: 326/425 (T=1425K, P=0.8atm, phi=0.8)
#   点火延迟: 2.340e-04 s
# 计算进度: 327/425 (T=1425K, P=0.8atm, phi=0.9)
#   点火延迟: 3.805e-02 s
# 计算进度: 328/425 (T=1425K, P=0.8atm, phi=1.0)
#   点火延迟: 6.011e-05 s
# 计算进度: 329/425 (T=1425K, P=0.8atm, phi=1.1)
#   点火延迟: 4.576e-05 s
# 计算进度: 330/425 (T=1425K, P=0.8atm, phi=1.2)
#   点火延迟: 4.101e-05 s
# 计算进度: 331/425 (T=1425K, P=0.9atm, phi=0.8)
#   点火延迟: 5.756e-05 s
# 计算进度: 332/425 (T=1425K, P=0.9atm, phi=0.9)
#   点火延迟: 6.306e-05 s
# 计算进度: 333/425 (T=1425K, P=0.9atm, phi=1.0)
#   点火延迟: 4.267e-05 s
# 计算进度: 334/425 (T=1425K, P=0.9atm, phi=1.1)
#   点火延迟: 3.829e-05 s
# 计算进度: 335/425 (T=1425K, P=0.9atm, phi=1.2)
#   点火延迟: 3.518e-05 s
# 计算进度: 336/425 (T=1425K, P=1.0atm, phi=0.8)
#   点火延迟: 4.028e-05 s
# 计算进度: 337/425 (T=1425K, P=1.0atm, phi=0.9)
#   点火延迟: 4.114e-05 s
# 计算进度: 338/425 (T=1425K, P=1.0atm, phi=1.0)
#   点火延迟: 3.435e-05 s
# 计算进度: 339/425 (T=1425K, P=1.0atm, phi=1.1)
#   点火延迟: 3.126e-05 s
# 计算进度: 340/425 (T=1425K, P=1.0atm, phi=1.2)
#   点火延迟: 2.822e-05 s
# 计算进度: 341/425 (T=1425K, P=1.1atm, phi=0.8)
#   点火延迟: 3.457e-05 s
# 计算进度: 342/425 (T=1425K, P=1.1atm, phi=0.9)
#   点火延迟: 3.487e-05 s
# 计算进度: 343/425 (T=1425K, P=1.1atm, phi=1.0)
#   点火延迟: 3.007e-05 s
# 计算进度: 344/425 (T=1425K, P=1.1atm, phi=1.1)
#   点火延迟: 2.575e-05 s
# 计算进度: 345/425 (T=1425K, P=1.1atm, phi=1.2)
#   点火延迟: 2.433e-05 s
# 计算进度: 346/425 (T=1425K, P=1.2atm, phi=0.8)
#   点火延迟: 2.925e-05 s
# 计算进度: 347/425 (T=1425K, P=1.2atm, phi=0.9)
#   点火延迟: 2.736e-05 s
# 计算进度: 348/425 (T=1425K, P=1.2atm, phi=1.0)
#   点火延迟: 2.499e-05 s
# 计算进度: 349/425 (T=1425K, P=1.2atm, phi=1.1)
#   点火延迟: 2.288e-05 s
# 计算进度: 350/425 (T=1425K, P=1.2atm, phi=1.2)
#   点火延迟: 2.108e-05 s
# 计算进度: 351/425 (T=1450K, P=0.8atm, phi=0.8)
#   点火延迟: 7.552e-04 s
# 计算进度: 352/425 (T=1450K, P=0.8atm, phi=0.9)
#   点火延迟: 6.687e-03 s
# 计算进度: 353/425 (T=1450K, P=0.8atm, phi=1.0)
#   点火延迟: 6.956e-05 s
# 计算进度: 354/425 (T=1450K, P=0.8atm, phi=1.1)
#   点火延迟: 4.846e-05 s
# 计算进度: 355/425 (T=1450K, P=0.8atm, phi=1.2)
#   点火延迟: 3.924e-05 s
# 计算进度: 356/425 (T=1450K, P=0.9atm, phi=0.8)
#   点火延迟: 6.298e-05 s
# 计算进度: 357/425 (T=1450K, P=0.9atm, phi=0.9)
#   点火延迟: 1.719e-04 s
# 计算进度: 358/425 (T=1450K, P=0.9atm, phi=1.0)
#   点火延迟: 4.557e-05 s
# 计算进度: 359/425 (T=1450K, P=0.9atm, phi=1.1)
#   点火延迟: 3.640e-05 s
# 计算进度: 360/425 (T=1450K, P=0.9atm, phi=1.2)
#   点火延迟: 3.225e-05 s
# 计算进度: 361/425 (T=1450K, P=1.0atm, phi=0.8)
#   点火延迟: 4.386e-05 s
# 计算进度: 362/425 (T=1450K, P=1.0atm, phi=0.9)
#   点火延迟: 4.951e-05 s
# 计算进度: 363/425 (T=1450K, P=1.0atm, phi=1.0)
#   点火延迟: 3.820e-05 s
# 计算进度: 364/425 (T=1450K, P=1.0atm, phi=1.1)
#   点火延迟: 3.050e-05 s
# 计算进度: 365/425 (T=1450K, P=1.0atm, phi=1.2)
#   点火延迟: 2.829e-05 s
# 计算进度: 366/425 (T=1450K, P=1.1atm, phi=0.8)
#   点火延迟: 3.337e-05 s
# 计算进度: 367/425 (T=1450K, P=1.1atm, phi=0.9)
#   点火延迟: 3.784e-05 s
# 计算进度: 368/425 (T=1450K, P=1.1atm, phi=1.0)
#   点火延迟: 3.045e-05 s
# 计算进度: 369/425 (T=1450K, P=1.1atm, phi=1.1)
#   点火延迟: 2.649e-05 s
# 计算进度: 370/425 (T=1450K, P=1.1atm, phi=1.2)
#   点火延迟: 2.417e-05 s
# 计算进度: 371/425 (T=1450K, P=1.2atm, phi=0.8)
#   点火延迟: 2.912e-05 s
# 计算进度: 372/425 (T=1450K, P=1.2atm, phi=0.9)
#   点火延迟: 2.874e-05 s
# 计算进度: 373/425 (T=1450K, P=1.2atm, phi=1.0)
#   点火延迟: 2.520e-05 s
# 计算进度: 374/425 (T=1450K, P=1.2atm, phi=1.1)
#   点火延迟: 2.224e-05 s
# 计算进度: 375/425 (T=1450K, P=1.2atm, phi=1.2)
#   点火延迟: 2.147e-05 s
# 计算进度: 376/425 (T=1475K, P=0.8atm, phi=0.8)
#   点火延迟: 3.329e-04 s
# 计算进度: 377/425 (T=1475K, P=0.8atm, phi=0.9)
#   点火延迟: 2.275e-04 s
# 计算进度: 378/425 (T=1475K, P=0.8atm, phi=1.0)
#   点火延迟: 6.559e-04 s
# 计算进度: 379/425 (T=1475K, P=0.8atm, phi=1.1)
#   点火延迟: 4.828e-05 s
# 计算进度: 380/425 (T=1475K, P=0.8atm, phi=1.2)
#   点火延迟: 3.970e-05 s
# 计算进度: 381/425 (T=1475K, P=0.9atm, phi=0.8)
#   点火延迟: 4.555e-04 s
# 计算进度: 382/425 (T=1475K, P=0.9atm, phi=0.9)
#   点火延迟: 1.862e-04 s
# 计算进度: 383/425 (T=1475K, P=0.9atm, phi=1.0)
#   点火延迟: 5.058e-05 s
# 计算进度: 384/425 (T=1475K, P=0.9atm, phi=1.1)
#   点火延迟: 3.800e-05 s
# 计算进度: 385/425 (T=1475K, P=0.9atm, phi=1.2)
#   点火延迟: 3.353e-05 s
# 计算进度: 386/425 (T=1475K, P=1.0atm, phi=0.8)
#   点火延迟: 4.790e-05 s
# 计算进度: 387/425 (T=1475K, P=1.0atm, phi=0.9)
#   点火延迟: 1.514e-04 s
# 计算进度: 388/425 (T=1475K, P=1.0atm, phi=1.0)
#   点火延迟: 3.971e-05 s
# 计算进度: 389/425 (T=1475K, P=1.0atm, phi=1.1)
#   点火延迟: 3.128e-05 s
# 计算进度: 390/425 (T=1475K, P=1.0atm, phi=1.2)
#   点火延迟: 2.750e-05 s
# 计算进度: 391/425 (T=1475K, P=1.1atm, phi=0.8)
#   点火延迟: 3.490e-05 s
# 计算进度: 392/425 (T=1475K, P=1.1atm, phi=0.9)
#   点火延迟: 3.826e-05 s
# 计算进度: 393/425 (T=1475K, P=1.1atm, phi=1.0)
#   点火延迟: 3.086e-05 s
# 计算进度: 394/425 (T=1475K, P=1.1atm, phi=1.1)
#   点火延迟: 2.507e-05 s
# 计算进度: 395/425 (T=1475K, P=1.1atm, phi=1.2)
#   点火延迟: 2.280e-05 s
# 计算进度: 396/425 (T=1475K, P=1.2atm, phi=0.8)
#   点火延迟: 2.972e-05 s
# 计算进度: 397/425 (T=1475K, P=1.2atm, phi=0.9)
#   点火延迟: 3.020e-05 s
# 计算进度: 398/425 (T=1475K, P=1.2atm, phi=1.0)
#   点火延迟: 2.429e-05 s
# 计算进度: 399/425 (T=1475K, P=1.2atm, phi=1.1)
#   点火延迟: 2.130e-05 s
# 计算进度: 400/425 (T=1475K, P=1.2atm, phi=1.2)
#   点火延迟: 2.038e-05 s
# 计算进度: 401/425 (T=1500K, P=0.8atm, phi=0.8)
#   点火延迟: 5.402e-04 s
# 计算进度: 402/425 (T=1500K, P=0.8atm, phi=0.9)
#   点火延迟: 4.890e-04 s
# 计算进度: 403/425 (T=1500K, P=0.8atm, phi=1.0)
#   点火延迟: 2.488e-04 s
# 计算进度: 404/425 (T=1500K, P=0.8atm, phi=1.1)
#   点火延迟: 4.848e-05 s
# 计算进度: 405/425 (T=1500K, P=0.8atm, phi=1.2)
#   点火延迟: 4.054e-05 s
# 计算进度: 406/425 (T=1500K, P=0.9atm, phi=0.8)
#   点火延迟: 3.448e-04 s
# 计算进度: 407/425 (T=1500K, P=0.9atm, phi=0.9)
#   点火延迟: 2.393e-04 s
# 计算进度: 408/425 (T=1500K, P=0.9atm, phi=1.0)
#   点火延迟: 8.284e-05 s
# 计算进度: 409/425 (T=1500K, P=0.9atm, phi=1.1)
#   点火延迟: 3.822e-05 s
# 计算进度: 410/425 (T=1500K, P=0.9atm, phi=1.2)
#   点火延迟: 3.200e-05 s
# 计算进度: 411/425 (T=1500K, P=1.0atm, phi=0.8)
#   点火延迟: 7.168e-05 s
# 计算进度: 412/425 (T=1500K, P=1.0atm, phi=0.9)
#   点火延迟: 4.155e-04 s
# 计算进度: 413/425 (T=1500K, P=1.0atm, phi=1.0)
#   点火延迟: 4.099e-05 s
# 计算进度: 414/425 (T=1500K, P=1.0atm, phi=1.1)
#   点火延迟: 2.957e-05 s
# 计算进度: 415/425 (T=1500K, P=1.0atm, phi=1.2)
#   点火延迟: 2.620e-05 s
# 计算进度: 416/425 (T=1500K, P=1.1atm, phi=0.8)
#   点火延迟: 3.686e-05 s
# 计算进度: 417/425 (T=1500K, P=1.1atm, phi=0.9)
#   点火延迟: 4.851e-05 s
# 计算进度: 418/425 (T=1500K, P=1.1atm, phi=1.0)
#   点火延迟: 3.283e-05 s
# 计算进度: 419/425 (T=1500K, P=1.1atm, phi=1.1)
#   点火延迟: 2.518e-05 s
# 计算进度: 420/425 (T=1500K, P=1.1atm, phi=1.2)
#   点火延迟: 2.349e-05 s
# 计算进度: 421/425 (T=1500K, P=1.2atm, phi=0.8)
#   点火延迟: 3.026e-05 s
# 计算进度: 422/425 (T=1500K, P=1.2atm, phi=0.9)
#   点火延迟: 3.038e-05 s
# 计算进度: 423/425 (T=1500K, P=1.2atm, phi=1.0)
#   点火延迟: 2.516e-05 s
# 计算进度: 424/425 (T=1500K, P=1.2atm, phi=1.1)
#   点火延迟: 2.255e-05 s
# 计算进度: 425/425 (T=1500K, P=1.2atm, phi=1.2)
#   点火延迟: 2.004e-05 s
#
# 总计算时间: 2.95 秒
#
# 结果已保存到 'ignition_delay_results_pure.csv'
#
# 前5行数据预览:
#    Temperature_K  Pressure_atm  Equivalence_Ratio  Ignition_Delay_s
# 0            1.1           0.8                0.8          0.000098
# 1            1.1           0.8                0.9          0.000100
# 2            1.1           0.8                1.0          0.000098
# 3            1.1           0.8                1.1          0.000097
# 4            1.1           0.8                1.2          0.000096
#
# 成功计算: 425/425
